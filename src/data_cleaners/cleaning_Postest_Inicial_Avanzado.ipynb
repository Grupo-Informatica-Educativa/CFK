# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Leer la data, filtrar solo por la Encuesta correspondiente al postest.

# %%
df_inicial = pd.read_csv('../../data/crudos/bd_full_inicial_corte27jun.csv',
                         error_bad_lines=False, warn_bad_lines=False,
                         low_memory=False)
df_avanzado = pd.read_csv('../../data/crudos/bd_full_avanzado_corte27jun.csv',
                          error_bad_lines=False, warn_bad_lines=False,
                          low_memory=False)

df_inicial = df_inicial[df_inicial.Encuesta == 'U4 Cuestionario Final (25 puntos)']
df_inicial.Pregunta = df_inicial.Pregunta.str.replace("\r", "")
df_avanzado = df_avanzado[df_avanzado.Encuesta == 'UA4 Cuestionario final (15 puntos)']

# %%
# PIVOT DATA
pivot_inicial = df_inicial.pivot_table(
    index=['Nombre', 'Apellido', 'Correo Electrónico', 'Curso', 'ID Asignado Por Moodle', 'Nombre De Usuario'],
    columns='Pregunta', 
    values='Respuesta', 
    aggfunc='first').reset_index()

pivot_avanzado = df_avanzado.pivot_table(
    index=['Nombre', 'Apellido', 'Correo Electrónico', 'Curso', 'ID Asignado Por Moodle', 'Nombre De Usuario'],
    columns='Pregunta', 
    values='Respuesta', 
    aggfunc='first').reset_index()

# %%
# Remove \n in columns
pivot_inicial.columns = [col.replace("\n", " ").strip() 
                        for col in pivot_inicial.columns]
pivot_avanzado.columns = [col.replace("\n", " ").strip() 
                        for col in pivot_avanzado.columns]

# %% [markdown]
# ## Limpieza de datos:

# %%
drop_both = ['Nombre', 'Apellido', 'Correo Electrónico', 'ID Asignado Por Moodle', 'Número de Cédula', 'Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:']
pivot_inicial.drop(columns=drop_both, inplace=True, errors='ignore')
pivot_avanzado.drop(columns=drop_both, inplace=True, errors='ignore')

# %%
a = [col for col in pivot_inicial.columns if 'Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:' in col]

a
# Out:
# []

# %% [markdown]
# ### Buscando la pregunta 11 que tiene igual nombre que la pregunta 13. (Para el posttest inicial)

# %%
##LISTO
print(pivot_inicial.shape)

df_preg11 = df_inicial[df_inicial.Respuesta.str.contains("Las mujeres en comparación con los hombres tienden a tener un sentido más refinado de la cultura y el buen gusto").fillna(False)][['Nombre De Usuario', 'Pregunta', 'Respuesta']]

pivot_preg11 = df_preg11.pivot_table(
    index='Nombre De Usuario',
    columns='Pregunta', 
    values='Respuesta', 
    aggfunc='first').reset_index()


# Remove \n in columns
pivot_preg11.columns = [col.replace("\n", " ").strip() 
                        for col in pivot_preg11.columns]
pivot_preg11.drop(columns='Agrega cualquier comentario o clarificación sobre las preguntas anteriores.', inplace=True, errors='ignore')
pivot_preg11.rename(columns={
    'Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:': '11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:'
}, inplace=True)
pivot_inicial = pivot_inicial.merge(pivot_preg11, on='Nombre De Usuario')
print(pivot_inicial.shape)
pivot_inicial
# Out:
# (4091, 28)
# (4091, 29)
#                        Curso Nombre De Usuario  \
# 0      Curso Inicial 2021 I4          19510505
# 1     Curso Inicial 2021 I28          37368988
# 2     Curso Inicial 2021 I28          88157902
# 3     Curso Inicial 2021 I64          93291177
# 4     Curso Inicial 2021 I37          98362173
# ...                      ...               ...
# 4086  Curso Inicial 2021 I26          13721233
# 4087  Curso Inicial 2021 I47          52154422
# 4088  Curso Inicial 2021 I22          71700763
# 4089  Curso Inicial 2021 I66        1065643965
# 4090  Curso Inicial 2021 I52          10274918
#
#      Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                                               ninguna
# 1              Excelentes las actividades desconectadas
# 2     En general se prefiere toda actividad donde el...
# 3                                      Sin comentarios.
# 4     El aprendizaje basado en proyectos es una gran...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  No conozco la estrategia de enseñanza Marcha S...
# 4088  La actividades desconectadas, promueven la int...
# 4089                                  SIN MAS QUE DECIR
# 4090  considero que la estrategia pedagógica de proy...
#
#      Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0     mas preguntas para temas de bloques y no de co...
# 1                                   Igualdad de generos
# 2     Desde hace un par de años hemos integrado el p...
# 3                                      Sin comentarios.
# 4     Hoy en día tenemos que propender por el desarr...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  Mis repuestas están basadas en el quehacer doc...
# 4088                                          Esta bien
# 4089                                  SIN MAS QUE DECIR
# 4090  al educando hay que llevarlo paso a paso en el...
#
#      Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?  \
# 0         El programa no funciona, falta incluir el Fin
# 1     El programa si funciona y lo puede implementar...
# 2     El programa si funciona y lo puede implementar...
# 3         El programa no funciona, falta incluir el Fin
# 4     El programa no funciona, debe capturar nuevame...
# ...                                                 ...
# 4086  El programa si funciona y lo puede implementar...
# 4087  El programa no funciona, debe capturar nuevame...
# 4088  El programa no funciona, debe capturar nuevame...
# 4089  El programa si funciona y lo puede implementar...
# 4090  El programa no funciona, debe capturar nuevame...
#
#      Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados sonverdaderos?  \
# 0                                          II solamente
# 1                                           I, II y III
# 2                                   No sé/No lo conozco
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                           II y III
# 4087                                No sé/No lo conozco
# 4088                                             I y II
# 4089                                           II y III
# 4090                                No sé/No lo conozco
#
#      Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?  \
# 0                                                     8
# 1                                                10 y 3
# 2                                                    10
# 3                                                10 y 3
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                 10
# 4087                                                 10
# 4088                                             10 y 3
# 4089                                                 10
# 4090                                                  3
#
#      Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?  \
# 0                                                     6
# 1                                                     3
# 2                                                     8
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                  6
# 4087                                                  8
# 4088                                                  2
# 4089                                                  6
# 4090                                                  3
#
#      Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:  \
# 0     Le explicaría la respuesta correcta - 6, Le su...
# 1     Le explicaría la respuesta correcta - 10, Le s...
# 2     Le explicaría la respuesta correcta - 5, Le su...
# 3     Le explicaría la respuesta correcta - 8, Le su...
# 4     Le explicaría la respuesta correcta - 5, Le su...
# ...                                                 ...
# 4086  Le explicaría la respuesta correcta - 2, Le su...
# 4087  Le explicaría la respuesta correcta - 8, Le su...
# 4088  Le explicaría la respuesta correcta - 7, Le su...
# 4089  Le explicaría la respuesta correcta - 5, Le su...
# 4090  Le explicaría la respuesta correcta - 3, Le su...
#
#      Edad (años)  ...  \
# 0             47  ...
# 1             49  ...
# 2             48  ...
# 3             53  ...
# 4             53  ...
# ...          ...  ...
# 4086          42  ...
# 4087          47  ...
# 4088          52  ...
# 4089          28  ...
# 4090          54  ...
#
#      Teniendo en cuenta el siguiente fragmento de código, Alejandra responde a la pregunta ¿Cuál será el valor final de “Y”? afirmando que el valor final será 44. El código retorna 120¿Qué opinas de la respuesta de Alejandra?  \
# 0                 Está equivocada, el resultado es 120.
# 1     Está equivocada, el resultado es 124, no está ...
# 2                 Está equivocada, el resultado es 120.
# 3                                   No sé/No lo conozco
# 4                 Está equivocada, el resultado es 120.
# ...                                                 ...
# 4086              Está equivocada, el resultado es 120.
# 4087                                No sé/No lo conozco
# 4088              Está equivocada, el resultado es 120.
# 4089              Está equivocada, el resultado es 120.
# 4090                                No sé/No lo conozco
#
#      Un ratón robot ha sido programado para seguir las siguientes instrucciones:  (1) Sigue hacia abajo hasta que haya un cruce a uno de los lados (2) Cuando encuentres un cruce, atraviésalo (3) Vuelve al paso (1).  Considera el siguiente laberinto para nuestro ratón robot. ¿En cuál de los tubos debería comenzar el robot para llegar al queso?  \
# 0                                                     3
# 1                                                     3
# 2                                                     3
# 3                                                     1
# 4                                                     3
# ...                                                 ...
# 4086                                                  4
# 4087                                                  3
# 4088                                                  3
# 4089                                                  3
# 4090                                                  1
#
#      ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)  \
# 0     Ciencias naturales y educación ambiental. - -1...
# 1     Ciencias naturales y educación ambiental. - 9,...
# 2     Ciencias naturales y educación ambiental. - -1...
# 3     Ciencias naturales y educación ambiental. - -1...
# 4     Ciencias naturales y educación ambiental. - 11...
# ...                                                 ...
# 4086  Ciencias naturales y educación ambiental. - -1...
# 4087  Ciencias naturales y educación ambiental. - 10...
# 4088  Ciencias naturales y educación ambiental. - 10...
# 4089  Ciencias naturales y educación ambiental. - -1...
# 4090  Ciencias naturales y educación ambiental. - 6,...
#
#      ¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)  \
# 0     Motivar que las niñas participen y sean escuch...
# 1     Motivar que las niñas participen y sean escuch...
# 2     Estimular el liderazgo femenino, por ejemplo, ...
# 3     Motivar que las niñas participen y sean escuch...
# 4     Motivar que las niñas participen y sean escuch...
# ...                                                 ...
# 4086  Motivar que las niñas participen y sean escuch...
# 4087  Motivar que las niñas participen y sean escuch...
# 4088  Motivar que las niñas participen y sean escuch...
# 4089  Prohibir y corregir los comentarios, actitudes...
# 4090  Motivar que las niñas participen y sean escuch...
#
#      ¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?  \
# 0     programa entrega valor entero el otro programa...
# 1                                    Comparando códigos
# 2     Realizando paso a paso cada uno de los dos pro...
# 3                     No tengo muy clara la información
# 4     Primero investigaría que significa este código...
# ...                                                 ...
# 4086  En el primer código imprimirá el Número 8En el...
# 4087  No puedo ayudarle a comprender, no conozco teo...
# 4088  Es una suma que en el primer código, se realiz...
# 4089           NO LOGRO ENTENDER EN TOTALIDAD EL CODIGO
# 4090  al código 2 se repite el codigo al final, debe...
#
#      ¿Es usted cabeza de hogar? ¿Es usted líder comunitario?  \
# 0                            Sí                           Sí
# 1                            No                           Sí
# 2                            Sí                           Sí
# 3                            Sí                           Sí
# 4                            Sí                           Sí
# ...                         ...                          ...
# 4086                         Sí                           Sí
# 4087                         No                           Sí
# 4088                         Sí                           Sí
# 4089                         No                           Sí
# 4090                         Sí                           Sí
#
#      ¿Estrato Socioeconómico?  \
# 0                         1-2
# 1                         1-2
# 2                         3-4
# 3                         3-4
# 4                         1-2
# ...                       ...
# 4086                      1-2
# 4087                      3-4
# 4088                      1-2
# 4089                      1-2
# 4090                      3-4
#
#      ¿Hace parte de alguno de los siguientes grupos étnicos?  \
# 0                             Ninguna de las anteriores
# 1                             Ninguna de las anteriores
# 2                             Ninguna de las anteriores
# 3                             Ninguna de las anteriores
# 4                             Ninguna de las anteriores
# ...                                                 ...
# 4086                          Ninguna de las anteriores
# 4087                          Ninguna de las anteriores
# 4088                          Ninguna de las anteriores
# 4089                          Ninguna de las anteriores
# 4090                          Ninguna de las anteriores
#
#      11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:
# 0     Que la mayoría de las mujeres no opte por área...
# 1     Que la mayoría de las mujeres no opte por área...
# 2     Que la mayoría de las mujeres no opte por área...
# 3     Que la mayoría de las mujeres no opte por área...
# 4     Que la mayoría de las mujeres no opte por área...
# ...                                                 ...
# 4086  Que la mayoría de las mujeres no opte por área...
# 4087  Que la mayoría de las mujeres no opte por área...
# 4088  Que la mayoría de las mujeres no opte por área...
# 4089  Que la mayoría de las mujeres no opte por área...
# 4090  Que la mayoría de las mujeres no opte por área...
#
# [4091 rows x 29 columns]

# %% [markdown]
# ### Buscar pregunta 13 también es sano, porque están combinadas la 11 y 13 (para el posttest inicial)

# %%
## LISTO
print(pivot_inicial.shape)

df_preg13 = df_inicial[df_inicial.Respuesta.str.contains("Sé cómo resolver los problemas técnicos cuando fallan las TIC").fillna(False)][['Nombre De Usuario', 'Pregunta', 'Respuesta']]

pivot_preg13 = df_preg13.pivot_table(
    index='Nombre De Usuario',
    columns='Pregunta', 
    values='Respuesta', 
    aggfunc='first').reset_index()


# Remove \n in columns
pivot_preg13.columns = [col.replace("\n", " ").strip() 
                        for col in pivot_preg13.columns]
pivot_preg13.rename(columns={
    'Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:': '13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:'
}, inplace=True)
pivot_preg13 = pivot_preg13.loc[:, ['Nombre De Usuario', '13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:']]
pivot_preg13
pivot_inicial = pivot_inicial.merge(pivot_preg13, on='Nombre De Usuario')
print(pivot_inicial.shape)
pivot_inicial
# Out:
# (4091, 29)
# (4091, 30)
#                        Curso Nombre De Usuario  \
# 0      Curso Inicial 2021 I4          19510505
# 1     Curso Inicial 2021 I28          37368988
# 2     Curso Inicial 2021 I28          88157902
# 3     Curso Inicial 2021 I64          93291177
# 4     Curso Inicial 2021 I37          98362173
# ...                      ...               ...
# 4086  Curso Inicial 2021 I26          13721233
# 4087  Curso Inicial 2021 I47          52154422
# 4088  Curso Inicial 2021 I22          71700763
# 4089  Curso Inicial 2021 I66        1065643965
# 4090  Curso Inicial 2021 I52          10274918
#
#      Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                                               ninguna
# 1              Excelentes las actividades desconectadas
# 2     En general se prefiere toda actividad donde el...
# 3                                      Sin comentarios.
# 4     El aprendizaje basado en proyectos es una gran...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  No conozco la estrategia de enseñanza Marcha S...
# 4088  La actividades desconectadas, promueven la int...
# 4089                                  SIN MAS QUE DECIR
# 4090  considero que la estrategia pedagógica de proy...
#
#      Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0     mas preguntas para temas de bloques y no de co...
# 1                                   Igualdad de generos
# 2     Desde hace un par de años hemos integrado el p...
# 3                                      Sin comentarios.
# 4     Hoy en día tenemos que propender por el desarr...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  Mis repuestas están basadas en el quehacer doc...
# 4088                                          Esta bien
# 4089                                  SIN MAS QUE DECIR
# 4090  al educando hay que llevarlo paso a paso en el...
#
#      Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?  \
# 0         El programa no funciona, falta incluir el Fin
# 1     El programa si funciona y lo puede implementar...
# 2     El programa si funciona y lo puede implementar...
# 3         El programa no funciona, falta incluir el Fin
# 4     El programa no funciona, debe capturar nuevame...
# ...                                                 ...
# 4086  El programa si funciona y lo puede implementar...
# 4087  El programa no funciona, debe capturar nuevame...
# 4088  El programa no funciona, debe capturar nuevame...
# 4089  El programa si funciona y lo puede implementar...
# 4090  El programa no funciona, debe capturar nuevame...
#
#      Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados sonverdaderos?  \
# 0                                          II solamente
# 1                                           I, II y III
# 2                                   No sé/No lo conozco
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                           II y III
# 4087                                No sé/No lo conozco
# 4088                                             I y II
# 4089                                           II y III
# 4090                                No sé/No lo conozco
#
#      Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?  \
# 0                                                     8
# 1                                                10 y 3
# 2                                                    10
# 3                                                10 y 3
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                 10
# 4087                                                 10
# 4088                                             10 y 3
# 4089                                                 10
# 4090                                                  3
#
#      Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?  \
# 0                                                     6
# 1                                                     3
# 2                                                     8
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                  6
# 4087                                                  8
# 4088                                                  2
# 4089                                                  6
# 4090                                                  3
#
#      Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:  \
# 0     Le explicaría la respuesta correcta - 6, Le su...
# 1     Le explicaría la respuesta correcta - 10, Le s...
# 2     Le explicaría la respuesta correcta - 5, Le su...
# 3     Le explicaría la respuesta correcta - 8, Le su...
# 4     Le explicaría la respuesta correcta - 5, Le su...
# ...                                                 ...
# 4086  Le explicaría la respuesta correcta - 2, Le su...
# 4087  Le explicaría la respuesta correcta - 8, Le su...
# 4088  Le explicaría la respuesta correcta - 7, Le su...
# 4089  Le explicaría la respuesta correcta - 5, Le su...
# 4090  Le explicaría la respuesta correcta - 3, Le su...
#
#      Edad (años)  ...  \
# 0             47  ...
# 1             49  ...
# 2             48  ...
# 3             53  ...
# 4             53  ...
# ...          ...  ...
# 4086          42  ...
# 4087          47  ...
# 4088          52  ...
# 4089          28  ...
# 4090          54  ...
#
#      Un ratón robot ha sido programado para seguir las siguientes instrucciones:  (1) Sigue hacia abajo hasta que haya un cruce a uno de los lados (2) Cuando encuentres un cruce, atraviésalo (3) Vuelve al paso (1).  Considera el siguiente laberinto para nuestro ratón robot. ¿En cuál de los tubos debería comenzar el robot para llegar al queso?  \
# 0                                                     3
# 1                                                     3
# 2                                                     3
# 3                                                     1
# 4                                                     3
# ...                                                 ...
# 4086                                                  4
# 4087                                                  3
# 4088                                                  3
# 4089                                                  3
# 4090                                                  1
#
#      ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)  \
# 0     Ciencias naturales y educación ambiental. - -1...
# 1     Ciencias naturales y educación ambiental. - 9,...
# 2     Ciencias naturales y educación ambiental. - -1...
# 3     Ciencias naturales y educación ambiental. - -1...
# 4     Ciencias naturales y educación ambiental. - 11...
# ...                                                 ...
# 4086  Ciencias naturales y educación ambiental. - -1...
# 4087  Ciencias naturales y educación ambiental. - 10...
# 4088  Ciencias naturales y educación ambiental. - 10...
# 4089  Ciencias naturales y educación ambiental. - -1...
# 4090  Ciencias naturales y educación ambiental. - 6,...
#
#      ¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)  \
# 0     Motivar que las niñas participen y sean escuch...
# 1     Motivar que las niñas participen y sean escuch...
# 2     Estimular el liderazgo femenino, por ejemplo, ...
# 3     Motivar que las niñas participen y sean escuch...
# 4     Motivar que las niñas participen y sean escuch...
# ...                                                 ...
# 4086  Motivar que las niñas participen y sean escuch...
# 4087  Motivar que las niñas participen y sean escuch...
# 4088  Motivar que las niñas participen y sean escuch...
# 4089  Prohibir y corregir los comentarios, actitudes...
# 4090  Motivar que las niñas participen y sean escuch...
#
#      ¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?  \
# 0     programa entrega valor entero el otro programa...
# 1                                    Comparando códigos
# 2     Realizando paso a paso cada uno de los dos pro...
# 3                     No tengo muy clara la información
# 4     Primero investigaría que significa este código...
# ...                                                 ...
# 4086  En el primer código imprimirá el Número 8En el...
# 4087  No puedo ayudarle a comprender, no conozco teo...
# 4088  Es una suma que en el primer código, se realiz...
# 4089           NO LOGRO ENTENDER EN TOTALIDAD EL CODIGO
# 4090  al código 2 se repite el codigo al final, debe...
#
#      ¿Es usted cabeza de hogar? ¿Es usted líder comunitario?  \
# 0                            Sí                           Sí
# 1                            No                           Sí
# 2                            Sí                           Sí
# 3                            Sí                           Sí
# 4                            Sí                           Sí
# ...                         ...                          ...
# 4086                         Sí                           Sí
# 4087                         No                           Sí
# 4088                         Sí                           Sí
# 4089                         No                           Sí
# 4090                         Sí                           Sí
#
#      ¿Estrato Socioeconómico?  \
# 0                         1-2
# 1                         1-2
# 2                         3-4
# 3                         3-4
# 4                         1-2
# ...                       ...
# 4086                      1-2
# 4087                      3-4
# 4088                      1-2
# 4089                      1-2
# 4090                      3-4
#
#      ¿Hace parte de alguno de los siguientes grupos étnicos?  \
# 0                             Ninguna de las anteriores
# 1                             Ninguna de las anteriores
# 2                             Ninguna de las anteriores
# 3                             Ninguna de las anteriores
# 4                             Ninguna de las anteriores
# ...                                                 ...
# 4086                          Ninguna de las anteriores
# 4087                          Ninguna de las anteriores
# 4088                          Ninguna de las anteriores
# 4089                          Ninguna de las anteriores
# 4090                          Ninguna de las anteriores
#
#      11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:  \
# 0     Que la mayoría de las mujeres no opte por área...
# 1     Que la mayoría de las mujeres no opte por área...
# 2     Que la mayoría de las mujeres no opte por área...
# 3     Que la mayoría de las mujeres no opte por área...
# 4     Que la mayoría de las mujeres no opte por área...
# ...                                                 ...
# 4086  Que la mayoría de las mujeres no opte por área...
# 4087  Que la mayoría de las mujeres no opte por área...
# 4088  Que la mayoría de las mujeres no opte por área...
# 4089  Que la mayoría de las mujeres no opte por área...
# 4090  Que la mayoría de las mujeres no opte por área...
#
#      13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:
# 0     Sé cómo resolver los problemas técnicos cuando...
# 1     Sé cómo resolver los problemas técnicos cuando...
# 2     Sé cómo resolver los problemas técnicos cuando...
# 3     Sé cómo resolver los problemas técnicos cuando...
# 4     Sé cómo resolver los problemas técnicos cuando...
# ...                                                 ...
# 4086  Sé cómo resolver los problemas técnicos cuando...
# 4087  Sé cómo resolver los problemas técnicos cuando...
# 4088  Sé cómo resolver los problemas técnicos cuando...
# 4089  Sé cómo resolver los problemas técnicos cuando...
# 4090  Sé cómo resolver los problemas técnicos cuando...
#
# [4091 rows x 30 columns]

# %% [markdown]
# ### Buscar pregunta 11 para el posttest avanzado

# %%
##LISTO
print(pivot_avanzado.shape)

df_preg11 = df_avanzado[df_avanzado.Respuesta.str.contains("Las mujeres en comparación con los hombres tienden a tener un sentido más refinado de la cultura y el buen gusto").fillna(False)][['Nombre De Usuario', 'Pregunta', 'Respuesta']]

pivot_preg11 = df_preg11.pivot_table(
    index='Nombre De Usuario',
    columns='Pregunta', 
    values='Respuesta', 
    aggfunc='first').reset_index()


# Remove \n in columns
pivot_preg11.columns = [col.replace("\n", " ").strip() 
                        for col in pivot_preg11.columns]
pivot_preg11.drop(columns='Agrega cualquier comentario o clarificación sobre las preguntas anteriores.', inplace=True, errors='ignore')
pivot_preg11.rename(columns={
    'Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:': '11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:'
}, inplace=True)
pivot_avanzado = pivot_avanzado.merge(pivot_preg11, on='Nombre De Usuario')
print(pivot_avanzado.shape)
pivot_avanzado
# Out:
# (796, 29)
# (796, 30)
#                        Curso Nombre De Usuario  \
# 0    Curso Avanzado 2021 A10          86067286
# 1    Curso Avanzado 2021 A24        1048690074
# 2    Curso Avanzado 2021 A19          93204985
# 3    Curso Avanzado 2021 A30          52012944
# 4     Curso Avanzado 2021 A4          78731135
# ..                       ...               ...
# 791  Curso Avanzado 2021 A24          13054101
# 792   Curso Avanzado 2021 A4          16459296
# 793  Curso Avanzado 2021 A12        1077428368
# 794   Curso Avanzado 2021 A3          52761755
# 795  Curso Avanzado 2021 A20          30324088
#
#     La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.                                            Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria? Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                             Imagen 1                                                                      Imagen 2                                                                                      Imagen 3                                                                      Imagen 4  \
# 0                                             Imagen 2
# 1                                             Imagen 3
# 2                                             Imagen 2
# 3                                             Imagen 2
# 4                                             Imagen 3
# ..                                                 ...
# 791                                           Imagen 3
# 792                                           Imagen 3
# 793                                           Imagen 4
# 794                                           Imagen 3
# 795                                           Imagen 3
#
#     María vive cerca de una montaña donde hace mucho calor en el día, pero mucho frío en la noche. Ella tiene calefacción y aire acondicionado en su apartamento, pero deben prenderlo desde la portería que está en el primer piso del edificio. María decidió     programar la Micro:bit para que envíe un mensaje de encender la calefacción cuando esté frío (menos de 15 grados) y encender el aire acondicionado cuando esté caliente (más de 25 grados). ¿Cuál de los siguientes programas le podríafuncionar a María?                \t\t\t\t\t\tImagen 1              \t\t\t\t\t\t                   \t\t\t\t\t\tImagen 2           \t                                                                 Imagen 3           \t                                                         Imagen 4  \
# 0                                             Imagen 3
# 1                                             Imagen 4
# 2                                             Imagen 3
# 3                                             Imagen 3
# 4                                             Imagen 3
# ..                                                 ...
# 791                                           Imagen 3
# 792                                           Imagen 3
# 793                                           Imagen 4
# 794                                           Imagen 3
# 795                                           Imagen 3
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0                                                  NaN
# 1                                           Capacitado
# 2    Desarrollar el pensamiento computacional es mu...
# 3                                    Ningún comentario
# 4    resalto el trabajo de las alumnas he tenido es...
# ..                                                 ...
# 791  A pesar que el Rector, no desea contratar serv...
# 792                                                NaN
# 793  Cuando somo capacitados esto nos lleva a capac...
# 794                                          No aplica
# 795  El desarrollo del pensamiento computacional pu...
#
#     Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                     Agregaria mas trabajo individual
# 1                                              Mejorar
# 2              Practicas con actividades desconectadas
# 3                                    Ningún comentario
# 4    el aprendizaje basado en proyectos permite al ...
# ..                                                 ...
# 791   Abp, esta enproceso de implementacion en la I.E.
# 792                                                NaN
# 793                            Poco a poco se avanza .
# 794                                          No aplica
# 795  Las actividades dependen de los diferentes con...
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                    Ningún comentario
# 4    la idea es que al programar se pongan aprueba ...
# ..                                                 ...
# 791  En la imagen 3, cuando el nivel de luz sea 100...
# 792  Son aburridoras y repetidas, las respondí como...
# 793       Felicitaciones por este maravilloso trabajo.
# 794         sería bueno condicionar también el horario
# 795  Es sencillo ahora que he trabajado con la micr...
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0    El ejemplo es la mejor forma de enseñar, mostr...
# 1                                         Compañerismo
# 2    Las mujeres tienen los mismos derechos de los ...
# 3                                    Ningún comentario
# 4                                          la igualdad
# ..                                                 ...
# 791  lo agradable sel error, es que te replantea re...
# 792                                                NaN
# 793  Estamos en el tiempo que toda persona hace uso...
# 794         Se requiere promover la igualdad de género
# 795  La igualdad debe ser tratada con tacto, porque...
#
#     Considera el siguiente segmento de código: ¿En qué orden deberá realizar las siguientes operaciones de manera que el valor de la variable “a” sea 15 al finalizar?  \
# 0                           delta, épsilon, alfa, gama
# 1                                  No sé/No lo conozco
# 2                           delta, épsilon, alfa, gama
# 3                           delta, épsilon, alfa, gama
# 4                     beta, épsilon, gama, delta, alfa
# ..                                                 ...
# 791                   alfa, delta, gama, beta, épsilon
# 792                                No sé/No lo conozco
# 793                   épsilon, delta, beta, gama, alfa
# 794                   épsilon, delta, beta, gama, alfa
# 795                   beta, épsilon, gama, delta, alfa
#
#     Considera el siguiente segmento de código:Seleccione el fragmento de código más correcto que resultará en el cálculo del área de la superficie de un cilindro, dada la fórmula:  \
# 0    x ::2 * 3.14 * r * r →     y ::h * x → areaSup...
# 1                                  No sé/No lo conozco
# 2    x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 3                                  No sé/No lo conozco
# 4    x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# ..                                                 ...
# 791  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 792                                No sé/No lo conozco
# 793  x ::2 * 3.14 * r * r →     y ::h * x → areaSup...
# 794  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 795  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
#
#      ... Su institución está en un contexto:  \
# 0    ...                              Urbano
# 1    ...                              Urbano
# 2    ...                               Rural
# 3    ...                              Urbano
# 4    ...                              Urbano
# ..   ...                                 ...
# 791  ...                               Rural
# 792  ...                              Urbano
# 793  ...                               Rural
# 794  ...                              Urbano
# 795  ...                              Urbano
#
#     Tim examina cada una de las siguientes piezas de código y responde que la primera termina con X siendo igual a 5, y la segunda con X siendo igual a 16.¿Cuál es el error conceptual de Tim?  \
# 0    Cree que, si la condición se cumple, todo lo q...
# 1    Cree que todo se ejecuta independiente de la c...
# 2    Cree que todo se ejecuta independiente de la c...
# 3    Cree que, si la condición se cumple, todo lo q...
# 4    Cree que, si la condición se cumple, todo lo q...
# ..                                                 ...
# 791  Cree que todo se ejecuta independiente de la c...
# 792  Cree que, si la condición se cumple, todo lo q...
# 793  Cree que, si la condición se cumple, todo lo q...
# 794  Cree que, si la condición se cumple, todo lo q...
# 795  Cree que todo se ejecuta independiente de la c...
#
#     ¿Cuál es su estrato socioeconómico?  \
# 0                                   3-4
# 1                                   3-4
# 2                                   1-2
# 3                                   1-2
# 4                                   3-4
# ..                                  ...
# 791                                 1-2
# 792                                 3-4
# 793                                 1-2
# 794                                 1-2
# 795                                 3-4
#
#     ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)  \
# 0    Ciencias naturales y educación ambiental. - -1...
# 1    Ciencias naturales y educación ambiental. - 11...
# 2    Ciencias naturales y educación ambiental. - 4,...
# 3    Ciencias naturales y educación ambiental. - 11...
# 4    Ciencias naturales y educación ambiental. - -1...
# ..                                                 ...
# 791  Ciencias naturales y educación ambiental. - -1...
# 792  Ciencias naturales y educación ambiental. - -1...
# 793  Ciencias naturales y educación ambiental. - 5,...
# 794  Ciencias naturales y educación ambiental. - 11...
# 795  Ciencias naturales y educación ambiental. - -1...
#
#     ¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)  \
# 0    1.\tPromover actividades que no perpetúen este...
# 1    1.\tPromover actividades que no perpetúen este...
# 2    2.\tRealizar clubes y actividades extracurricu...
# 3    1.\tPromover actividades que no perpetúen este...
# 4    5.\tDar referencias o modelos de mujeres desta...
# ..                                                 ...
# 791  1.\tPromover actividades que no perpetúen este...
# 792  1.\tPromover actividades que no perpetúen este...
# 793  1.\tPromover actividades que no perpetúen este...
# 794  1.\tPromover actividades que no perpetúen este...
# 795  4.\tDedicar una clase exclusiva a reflexionar ...
#
#     ¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Es importante dar a conocer las normas del jue...
# 4     se prueba cada codigo hasta definir su resultado
# ..                                                 ...
# 791  El juego es de un numero de Azar cuyo rango es...
# 792                                                NaN
# 793                                                NaN
# 794  Primero con una actividad desconectada, luego ...
# 795  Con una actividad desconectada para manejar nú...
#
#     ¿Es usted cabeza de hogar? ¿Es usted líder comunitario?  \
# 0                           Sí                           Sí
# 1                           Sí                           Sí
# 2                           Sí                           Sí
# 3                           Sí                           Sí
# 4                           No                           Sí
# ..                         ...                          ...
# 791                         Sí                           Sí
# 792                         Sí                           Sí
# 793                         Sí                           Sí
# 794                         Sí                           Sí
# 795                         Sí                           Sí
#
#     ¿Hace parte de alguno de los siguientes grupos étnicos?  \
# 0                            Ninguna de las anteriores
# 1                            Ninguna de las anteriores
# 2                            Ninguna de las anteriores
# 3                            Ninguna de las anteriores
# 4                            Ninguna de las anteriores
# ..                                                 ...
# 791                                   Afrodescendiente
# 792                          Ninguna de las anteriores
# 793                                   Afrodescendiente
# 794                          Ninguna de las anteriores
# 795                          Ninguna de las anteriores
#
#     11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:
# 0    Es preferible que las mujeres enseñen ciencias...
# 1    Es preferible que las mujeres enseñen ciencias...
# 2    Es preferible que las mujeres enseñen ciencias...
# 3    Es preferible que las mujeres enseñen ciencias...
# 4    Es preferible que las mujeres enseñen ciencias...
# ..                                                 ...
# 791  Es preferible que las mujeres enseñen ciencias...
# 792  Es preferible que las mujeres enseñen ciencias...
# 793  Es preferible que las mujeres enseñen ciencias...
# 794  Es preferible que las mujeres enseñen ciencias...
# 795  Es preferible que las mujeres enseñen ciencias...
#
# [796 rows x 30 columns]

# %% [markdown]
# ### Buscar pregunta 13 que es igual a la 11 (para el posttest avanzado)

# %%
## LISTO
print(pivot_avanzado.shape)

df_preg13 = df_avanzado[df_avanzado.Respuesta.str.contains("Sé cómo resolver los problemas técnicos cuando fallan las TIC").fillna(False)][['Nombre De Usuario', 'Pregunta', 'Respuesta']]

pivot_preg13 = df_preg13.pivot_table(
    index='Nombre De Usuario',
    columns='Pregunta', 
    values='Respuesta', 
    aggfunc='first').reset_index()


# Remove \n in columns
pivot_preg13.columns = [col.replace("\n", " ").strip() 
                        for col in pivot_preg13.columns]
pivot_preg13
pivot_preg13.rename(columns={
    'Por favor evalúe los siguientes enunciados de acuerdo con su experiencia': '13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:'
}, inplace=True)

pivot_preg13
pivot_preg13 = pivot_preg13.loc[:, ['Nombre De Usuario', '13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:']]
pivot_avanzado = pivot_avanzado.merge(pivot_preg13, on='Nombre De Usuario')
print(pivot_avanzado.shape)
pivot_avanzado
# Out:
# (796, 30)
# (796, 31)
#                        Curso Nombre De Usuario  \
# 0    Curso Avanzado 2021 A10          86067286
# 1    Curso Avanzado 2021 A24        1048690074
# 2    Curso Avanzado 2021 A19          93204985
# 3    Curso Avanzado 2021 A30          52012944
# 4     Curso Avanzado 2021 A4          78731135
# ..                       ...               ...
# 791  Curso Avanzado 2021 A24          13054101
# 792   Curso Avanzado 2021 A4          16459296
# 793  Curso Avanzado 2021 A12        1077428368
# 794   Curso Avanzado 2021 A3          52761755
# 795  Curso Avanzado 2021 A20          30324088
#
#     La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.                                            Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria? Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                             Imagen 1                                                                      Imagen 2                                                                                      Imagen 3                                                                      Imagen 4  \
# 0                                             Imagen 2
# 1                                             Imagen 3
# 2                                             Imagen 2
# 3                                             Imagen 2
# 4                                             Imagen 3
# ..                                                 ...
# 791                                           Imagen 3
# 792                                           Imagen 3
# 793                                           Imagen 4
# 794                                           Imagen 3
# 795                                           Imagen 3
#
#     María vive cerca de una montaña donde hace mucho calor en el día, pero mucho frío en la noche. Ella tiene calefacción y aire acondicionado en su apartamento, pero deben prenderlo desde la portería que está en el primer piso del edificio. María decidió     programar la Micro:bit para que envíe un mensaje de encender la calefacción cuando esté frío (menos de 15 grados) y encender el aire acondicionado cuando esté caliente (más de 25 grados). ¿Cuál de los siguientes programas le podríafuncionar a María?                \t\t\t\t\t\tImagen 1              \t\t\t\t\t\t                   \t\t\t\t\t\tImagen 2           \t                                                                 Imagen 3           \t                                                         Imagen 4  \
# 0                                             Imagen 3
# 1                                             Imagen 4
# 2                                             Imagen 3
# 3                                             Imagen 3
# 4                                             Imagen 3
# ..                                                 ...
# 791                                           Imagen 3
# 792                                           Imagen 3
# 793                                           Imagen 4
# 794                                           Imagen 3
# 795                                           Imagen 3
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0                                                  NaN
# 1                                           Capacitado
# 2    Desarrollar el pensamiento computacional es mu...
# 3                                    Ningún comentario
# 4    resalto el trabajo de las alumnas he tenido es...
# ..                                                 ...
# 791  A pesar que el Rector, no desea contratar serv...
# 792                                                NaN
# 793  Cuando somo capacitados esto nos lleva a capac...
# 794                                          No aplica
# 795  El desarrollo del pensamiento computacional pu...
#
#     Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                     Agregaria mas trabajo individual
# 1                                              Mejorar
# 2              Practicas con actividades desconectadas
# 3                                    Ningún comentario
# 4    el aprendizaje basado en proyectos permite al ...
# ..                                                 ...
# 791   Abp, esta enproceso de implementacion en la I.E.
# 792                                                NaN
# 793                            Poco a poco se avanza .
# 794                                          No aplica
# 795  Las actividades dependen de los diferentes con...
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                    Ningún comentario
# 4    la idea es que al programar se pongan aprueba ...
# ..                                                 ...
# 791  En la imagen 3, cuando el nivel de luz sea 100...
# 792  Son aburridoras y repetidas, las respondí como...
# 793       Felicitaciones por este maravilloso trabajo.
# 794         sería bueno condicionar también el horario
# 795  Es sencillo ahora que he trabajado con la micr...
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0    El ejemplo es la mejor forma de enseñar, mostr...
# 1                                         Compañerismo
# 2    Las mujeres tienen los mismos derechos de los ...
# 3                                    Ningún comentario
# 4                                          la igualdad
# ..                                                 ...
# 791  lo agradable sel error, es que te replantea re...
# 792                                                NaN
# 793  Estamos en el tiempo que toda persona hace uso...
# 794         Se requiere promover la igualdad de género
# 795  La igualdad debe ser tratada con tacto, porque...
#
#     Considera el siguiente segmento de código: ¿En qué orden deberá realizar las siguientes operaciones de manera que el valor de la variable “a” sea 15 al finalizar?  \
# 0                           delta, épsilon, alfa, gama
# 1                                  No sé/No lo conozco
# 2                           delta, épsilon, alfa, gama
# 3                           delta, épsilon, alfa, gama
# 4                     beta, épsilon, gama, delta, alfa
# ..                                                 ...
# 791                   alfa, delta, gama, beta, épsilon
# 792                                No sé/No lo conozco
# 793                   épsilon, delta, beta, gama, alfa
# 794                   épsilon, delta, beta, gama, alfa
# 795                   beta, épsilon, gama, delta, alfa
#
#     Considera el siguiente segmento de código:Seleccione el fragmento de código más correcto que resultará en el cálculo del área de la superficie de un cilindro, dada la fórmula:  \
# 0    x ::2 * 3.14 * r * r →     y ::h * x → areaSup...
# 1                                  No sé/No lo conozco
# 2    x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 3                                  No sé/No lo conozco
# 4    x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# ..                                                 ...
# 791  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 792                                No sé/No lo conozco
# 793  x ::2 * 3.14 * r * r →     y ::h * x → areaSup...
# 794  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 795  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 791  ...
# 792  ...
# 793  ...
# 794  ...
# 795  ...
#
#     Tim examina cada una de las siguientes piezas de código y responde que la primera termina con X siendo igual a 5, y la segunda con X siendo igual a 16.¿Cuál es el error conceptual de Tim?  \
# 0    Cree que, si la condición se cumple, todo lo q...
# 1    Cree que todo se ejecuta independiente de la c...
# 2    Cree que todo se ejecuta independiente de la c...
# 3    Cree que, si la condición se cumple, todo lo q...
# 4    Cree que, si la condición se cumple, todo lo q...
# ..                                                 ...
# 791  Cree que todo se ejecuta independiente de la c...
# 792  Cree que, si la condición se cumple, todo lo q...
# 793  Cree que, si la condición se cumple, todo lo q...
# 794  Cree que, si la condición se cumple, todo lo q...
# 795  Cree que todo se ejecuta independiente de la c...
#
#     ¿Cuál es su estrato socioeconómico?  \
# 0                                   3-4
# 1                                   3-4
# 2                                   1-2
# 3                                   1-2
# 4                                   3-4
# ..                                  ...
# 791                                 1-2
# 792                                 3-4
# 793                                 1-2
# 794                                 1-2
# 795                                 3-4
#
#     ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)  \
# 0    Ciencias naturales y educación ambiental. - -1...
# 1    Ciencias naturales y educación ambiental. - 11...
# 2    Ciencias naturales y educación ambiental. - 4,...
# 3    Ciencias naturales y educación ambiental. - 11...
# 4    Ciencias naturales y educación ambiental. - -1...
# ..                                                 ...
# 791  Ciencias naturales y educación ambiental. - -1...
# 792  Ciencias naturales y educación ambiental. - -1...
# 793  Ciencias naturales y educación ambiental. - 5,...
# 794  Ciencias naturales y educación ambiental. - 11...
# 795  Ciencias naturales y educación ambiental. - -1...
#
#     ¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)  \
# 0    1.\tPromover actividades que no perpetúen este...
# 1    1.\tPromover actividades que no perpetúen este...
# 2    2.\tRealizar clubes y actividades extracurricu...
# 3    1.\tPromover actividades que no perpetúen este...
# 4    5.\tDar referencias o modelos de mujeres desta...
# ..                                                 ...
# 791  1.\tPromover actividades que no perpetúen este...
# 792  1.\tPromover actividades que no perpetúen este...
# 793  1.\tPromover actividades que no perpetúen este...
# 794  1.\tPromover actividades que no perpetúen este...
# 795  4.\tDedicar una clase exclusiva a reflexionar ...
#
#     ¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Es importante dar a conocer las normas del jue...
# 4     se prueba cada codigo hasta definir su resultado
# ..                                                 ...
# 791  El juego es de un numero de Azar cuyo rango es...
# 792                                                NaN
# 793                                                NaN
# 794  Primero con una actividad desconectada, luego ...
# 795  Con una actividad desconectada para manejar nú...
#
#     ¿Es usted cabeza de hogar? ¿Es usted líder comunitario?  \
# 0                           Sí                           Sí
# 1                           Sí                           Sí
# 2                           Sí                           Sí
# 3                           Sí                           Sí
# 4                           No                           Sí
# ..                         ...                          ...
# 791                         Sí                           Sí
# 792                         Sí                           Sí
# 793                         Sí                           Sí
# 794                         Sí                           Sí
# 795                         Sí                           Sí
#
#     ¿Hace parte de alguno de los siguientes grupos étnicos?  \
# 0                            Ninguna de las anteriores
# 1                            Ninguna de las anteriores
# 2                            Ninguna de las anteriores
# 3                            Ninguna de las anteriores
# 4                            Ninguna de las anteriores
# ..                                                 ...
# 791                                   Afrodescendiente
# 792                          Ninguna de las anteriores
# 793                                   Afrodescendiente
# 794                          Ninguna de las anteriores
# 795                          Ninguna de las anteriores
#
#     11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:  \
# 0    Es preferible que las mujeres enseñen ciencias...
# 1    Es preferible que las mujeres enseñen ciencias...
# 2    Es preferible que las mujeres enseñen ciencias...
# 3    Es preferible que las mujeres enseñen ciencias...
# 4    Es preferible que las mujeres enseñen ciencias...
# ..                                                 ...
# 791  Es preferible que las mujeres enseñen ciencias...
# 792  Es preferible que las mujeres enseñen ciencias...
# 793  Es preferible que las mujeres enseñen ciencias...
# 794  Es preferible que las mujeres enseñen ciencias...
# 795  Es preferible que las mujeres enseñen ciencias...
#
#     13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:
# 0    Sé cómo resolver los problemas técnicos cuando...
# 1    Sé cómo resolver los problemas técnicos cuando...
# 2    Sé cómo resolver los problemas técnicos cuando...
# 3    Sé cómo resolver los problemas técnicos cuando...
# 4    Sé cómo resolver los problemas técnicos cuando...
# ..                                                 ...
# 791  Sé cómo resolver los problemas técnicos cuando...
# 792  Sé cómo resolver los problemas técnicos cuando...
# 793  Sé cómo resolver los problemas técnicos cuando...
# 794  Sé cómo resolver los problemas técnicos cuando...
# 795  Sé cómo resolver los problemas técnicos cuando...
#
# [796 rows x 31 columns]

# %% [markdown]
# ### Columnas en común entre los posttest inicial y avanzado

# %%
compartidas = {
    'Nombre De Usuario': 'Identificación',
    'Edad (años)': 'Edad',
    'Su institución está en un contexto:': 'Contexto IE',
    'Curso': 'Curso',
    'Género': 'Género',
    '¿Hace parte de alguno de los siguientes grupos étnicos?': 'Grupo Étnico',
    'Estrato': 'Estrato',
    '¿Es usted cabeza de hogar?': '¿Es usted cabeza de hogar?',
    '¿Es usted líder comunitario?': '¿Es usted líder comunitario?',
    "¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)": "9. ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)",
    '¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)': '10. ¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)',
    # AMBIGUO 11 Y 13 'Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:': '11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:',
    # AMBIGUO 12, 14, 17, 21, 33INICIAL, 31AVANZADO  'Agrega cualquier comentario o clarificación sobre las preguntas anteriores.': '12. Agrega cualquier comentario o clarificación sobre las preguntas anteriores.',
    'Por favor evalúe las siguientes afirmaciones según qué tan de acuerdo está usted con enseñar las siguientes prácticas como objetivos de aprendizaje relacionados con el pensamiento computacional:': '15. Por favor evalúe las siguientes afirmaciones según qué tan de acuerdo está usted con enseñar las siguientes prácticas como objetivos de aprendizaje relacionados con el pensamiento computacional:',
    'Por favor evalúe los siguientes enunciados de acuerdo con qué tan preparado(a) se siente para integrar el pensamiento computacional en sus cursos:': '16. Por favor evalúe los siguientes enunciados de acuerdo con qué tan preparado(a) se siente para integrar el pensamiento computacional en sus cursos:',
    'En una escala de 1 a 10 (donde 10 es muy a menudo), con qué frecuencia utilizarías las siguientes prácticas pedagógicas para enseñar pensamiento computacional.': '18. En una escala de 1 a 10 (donde 10 es muy a menudo), con qué frecuencia utilizarías las siguientes prácticas pedagógicas para enseñar pensamiento computacional.',
    'Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.': '19. Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.',
    'Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:': '20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:',
    
 
}

# %% [markdown]
# ### Limpieza posttest inicial

# %%
inicial = {
    '¿Estrato Socioeconómico?': 'Estrato',

    'La docente Margarita decidió hacer que sus estudiantes de segundo de primaria utilicen los computadores del colegio para predecir el clima de una semana (temperatura, precipitaciones, y viento). Cada estudiante debe dibujar cómo se verá el clima en la ciudad en dicha semana. Margarita, creó un archivo compartido donde los estudiantes ingresarán la información. Luego tomaron las predicciones de modelos de Internet y los ingresaron en el mismo documento compartido. Durante una semana tomaron los datos reales, y luego, proyectaron en el tablero los datos predichos por los estudiantes, los del modelo de Internet, y los datos reales. Al finalizar, Margarita les mostró a los estudiantes cómo hacer un gráfico para comparar los diferentes datos.    ¿Está Margarita desarrollando el pensamiento computacional de sus estudiantes? Seleccione todas las respuestas que considere correctas.': '22. La docente Margarita decidió hacer que sus estudiantes de segundo de primaria utilicen los computadores del colegio para predecir el clima de una semana (temperatura, precipitaciones, y viento). Cada estudiante debe dibujar cómo se verá el clima en la ciudad en dicha semana. Margarita, creó un archivo compartido donde los estudiantes ingresarán la información. Luego tomaron las predicciones de modelos de Internet y los ingresaron en el mismo documento compartido. Durante una semana tomaron los datos reales, y luego, proyectaron en el tablero los datos predichos por los estudiantes, los del modelo de Internet, y los datos reales. Al finalizar, Margarita les mostró a los estudiantes cómo hacer un gráfico para comparar los diferentes datos.    ¿Está Margarita desarrollando el pensamiento computacional de sus estudiantes? Seleccione todas las respuestas que considere correctas.',

    'La cafetería del colegio empacó almuerzos iguales para todos los estudiantes, menos los de Juan Arias y María Vásquez que no pueden comer huevo. Los almuerzos están marcados con el apellido de los estudiantes y organizados alfabéticamente. Para verificar que su almuerzo cumple con la restricción alimenticia María con ayuda de su profesor buscan en las cajas. María sabe que su almuerzo debe estar al final, así que busca hasta que encuentre una caja que comience por una letra cerca de la V. Cuando encuentra una que comienza con Trujillo, mira el último almuerzo de esa caja y se da cuenta que termina en Zapata. Así, María se da cuenta que su almuerzo debe estar allí.  ¿Está María usando el pensamiento computacional para encontrar su almuerzo? Seleccione todas las respuestas que considere correctas.': '23. La cafetería del colegio empacó almuerzos iguales para todos los estudiantes, menos los de Juan Arias y María Vásquez que no pueden comer huevo. Los almuerzos están marcados con el apellido de los estudiantes y organizados alfabéticamente. Para verificar que su almuerzo cumple con la restricción alimenticia María con ayuda de su profesor buscan en las cajas. María sabe que su almuerzo debe estar al final, así que busca hasta que encuentre una caja que comience por una letra cerca de la V. Cuando encuentra una que comienza con Trujillo, mira el último almuerzo de esa caja y se da cuenta que termina en Zapata. Así, María se da cuenta que su almuerzo debe estar allí.  ¿Está María usando el pensamiento computacional para encontrar su almuerzo? Seleccione todas las respuestas que considere correctas.',

    'Un ratón robot ha sido programado para seguir las siguientes instrucciones:  (1) Sigue hacia abajo hasta que haya un cruce a uno de los lados (2) Cuando encuentres un cruce, atraviésalo (3) Vuelve al paso (1).  Considera el siguiente laberinto para nuestro ratón robot. ¿En cuál de los tubos debería comenzar el robot para llegar al queso?': '24. Un ratón robot ha sido programado para seguir las siguientes instrucciones:  (1) Sigue hacia abajo hasta que haya un cruce a uno de los lados (2) Cuando encuentres un cruce, atraviésalo (3) Vuelve al paso (1).  Considera el siguiente laberinto para nuestro ratón robot. ¿En cuál de los tubos debería comenzar el robot para llegar al queso?',

    'Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?': '25. Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?',

    'Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?': '26. Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?',

    'Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?': '27. Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?',

    'Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados sonverdaderos?': '28. Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados son verdaderos?',

    'Suponiendo que “a” y “b” son variables booleanas. Considera la siguiente expresión lógica:¿Cuál de las siguientes afirmaciones describe de manera más precisa la evaluación de las expresiones?': '29. Suponiendo que “a” y “b” son variables booleanas. Considera la siguiente expresión lógica:¿Cuál de las siguientes afirmaciones describe de manera más precisa la evaluación de las expresiones?',

    'La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.   Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                 Imagen 1                 Imagen 2                       Imagen 3                 Imagen 4': '30. La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.   Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                 Imagen 1                 Imagen 2                       Imagen 3                 Imagen 4',

    'Teniendo en cuenta el siguiente fragmento de código, Alejandra responde a la pregunta ¿Cuál será el valor final de “Y”? afirmando que el valor final será 44. El código retorna 120¿Qué opinas de la respuesta de Alejandra?': '31. Teniendo en cuenta el siguiente fragmento de código, Alejandra responde a la pregunta ¿Cuál será el valor final de “Y”? afirmando que el valor final será 44. El código retorna 120¿Qué opinas de la respuesta de Alejandra?',

    '¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?': '32. ¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?',


}

# %%
def add_columns(df1, df2):
    for col in df2.columns:
        df1[col] = df2[col]


def divide_question_YES_NO(num_col, str_col, opciones, df):
    for i, op in enumerate(opciones):
        print(num_col, i)
        subpreg = f'{num_col}.{i+1} {op}'
        mask = df[str_col].str.contains(op, na=False)
        df[subpreg] = mask
        df.loc[:, subpreg] = df.loc[:, subpreg].replace({True: 'SI', False: 'NO'})

de_acuerdo= {
    1: 'Totalmente en desacuerdo', 
    2: 'En desacuerdo',
    3: 'Neutro',
    4: 'De acuerdo',
    5: 'Totalmente de acuerdo'
}

# %%
pivot_inicial.rename(columns=compartidas, inplace=True)
pivot_inicial.rename(columns=inicial, inplace=True)
pivot_inicial.to_excel('pivot_inicial_renamed.xlsx', index=False, encoding='utf-8-sig')

# %%
## Pregunta 9
col = "9. ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)"
pivot_inicial[col] = pivot_inicial[col].str.replace('-1', '0')
df_res = pivot_inicial[col].str.split(r'\b\D+\b', expand=True)
df_res.rename({
    1: '9.1 Ciencias naturales y educación ambiental',
    2: '9.2 Ciencias sociales, historia, geografía, constitución política y democracia',
    3: '9.3 Educación artística',
    4: '9.4 Educación ética y en valores humanos',
    5: '9.5 Educación física, recreación y deportes',
    6: '9.6 Educación religiosa',
    7: '9.7 Humanidades, lengua castellana e idiomas extranjeros',
    8: '9.8 Matemáticas',
    9: '9.9 Tecnología e informática',
    10: '9.10 Otro'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_inicial.shape)
add_columns(pivot_inicial, df_res)
print(pivot_inicial.shape)
# Out:
# (4091, 30)
# (4091, 40)

# %%
## Pregunta 10
col = "10. ¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)"
opciones = [
    "Motivar que las niñas participen y sean escuchadas, por ejemplo, alternándolas con los niños.",
    "Estimular el liderazgo femenino, por ejemplo, que las niñas y adolescentes sean representantes de grupo.",
    "Generar espacios de confianza para las niñas, por ejemplo, realizando reflexiones sobre el género al comienzo de la clase.",
    "Prohibir y corregir los comentarios, actitudes y acciones sexistas.",
    "Utilizar lenguaje inclusivo y no realizar estereotipos de género, por ejemplo, decir “todas las personas” en vez de “todos los niños” o evitar decir que las niñas son delicadas."
]
print(pivot_inicial.shape)

divide_question_YES_NO(10, col, opciones, pivot_inicial)
pivot_inicial.drop(columns=col, inplace=True)
print(pivot_inicial.shape)
# Out:
# (4091, 40)
# 10 0
# 10 1
# 10 2
# 10 3
# 10 4
# (4091, 44)

# %%
## Pregunta 11
col = "11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:"
df_res = pivot_inicial[col].str.split(r'\b\D+\b', expand=True)
df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)
df_res.rename({
    1: '11.1 Que la mayoría de las mujeres no opte por áreas exactas es simplemente una cuestión de preferencias.',
    2: '11.2 Por su esencia una mujer tiene mejor desempeño en un proyecto de alto impacto social que en un proyecto de robótica industrial.',
    3: '11.3 Que los varones lideren áreas científicas y tecnológicas indica una forma de injusticia social.',
    4: '11.4 Que la mayoría de las personas en artes y humanidades sean mujeres es muestra de su sensibilidad.',
    5: '11.5 Es natural que los hombres sean buenos para los números y las mujeres para las letras.',
    6: '11.6 Muchas mujeres se caracterizan por una pureza que pocos hombres poseen.',
    7: '11.7 Las mujeres deben ser queridas y protegidas por los hombres.',
    8: '11.8 Todo hombre debe tener una mujer a quien amar.',
    9: '11.9 El hombre está incompleto sin la mujer.',
    10: '11.10 Las mujeres en comparación con los hombres tienden a tener un sentido más refinado de la cultura y el buen gusto.',
    11: '11.11 Los hombres deberían estar dispuestos a sacrificar su propio bienestar con el fin de proveer seguridad económica a las mujeres.'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)


print(pivot_inicial.shape)
add_columns(pivot_inicial, df_res)
print(pivot_inicial.shape)
# Out:
# (4091, 44)
# (4091, 55)

# %%
## Pregunta 13
col = "13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:"
df_res = pivot_inicial[col].str.split(r'\b\D+\b', expand=True)
df_res
df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)

df_res.rename({
    1: '13.1 Sé cómo resolver los problemas técnicos cuando fallan las TIC',
    2: '13.2 Puedo aprender sobre nuevas tecnologías fácilmente',
    3: '13.3 Sé cómo usar las TIC con los estudiantes en clase',
    4: '13.4 Me apoyo en mis colegas para resolver problemas sobre cómo trabajar algún tema',
    5: '13.5 Puedo hablar con otros docentes sobre el diseño de cursos',
    6: '13.6 Siento que tengo apoyo de otros docentes para el diseño de mis cursos',
    7: '13.7 No tengo con quién conversar sobre el diseño de mis cursos'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_inicial.shape)
add_columns(pivot_inicial, df_res)
print(pivot_inicial.shape)
pivot_inicial
# Out:
# (4091, 55)
# (4091, 62)
#                        Curso Identificación  \
# 0      Curso Inicial 2021 I4       19510505
# 1     Curso Inicial 2021 I28       37368988
# 2     Curso Inicial 2021 I28       88157902
# 3     Curso Inicial 2021 I64       93291177
# 4     Curso Inicial 2021 I37       98362173
# ...                      ...            ...
# 4086  Curso Inicial 2021 I26       13721233
# 4087  Curso Inicial 2021 I47       52154422
# 4088  Curso Inicial 2021 I22       71700763
# 4089  Curso Inicial 2021 I66     1065643965
# 4090  Curso Inicial 2021 I52       10274918
#
#      19. Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                                               ninguna
# 1              Excelentes las actividades desconectadas
# 2     En general se prefiere toda actividad donde el...
# 3                                      Sin comentarios.
# 4     El aprendizaje basado en proyectos es una gran...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  No conozco la estrategia de enseñanza Marcha S...
# 4088  La actividades desconectadas, promueven la int...
# 4089                                  SIN MAS QUE DECIR
# 4090  considero que la estrategia pedagógica de proy...
#
#      Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0     mas preguntas para temas de bloques y no de co...
# 1                                   Igualdad de generos
# 2     Desde hace un par de años hemos integrado el p...
# 3                                      Sin comentarios.
# 4     Hoy en día tenemos que propender por el desarr...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  Mis repuestas están basadas en el quehacer doc...
# 4088                                          Esta bien
# 4089                                  SIN MAS QUE DECIR
# 4090  al educando hay que llevarlo paso a paso en el...
#
#      25. Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?  \
# 0         El programa no funciona, falta incluir el Fin
# 1     El programa si funciona y lo puede implementar...
# 2     El programa si funciona y lo puede implementar...
# 3         El programa no funciona, falta incluir el Fin
# 4     El programa no funciona, debe capturar nuevame...
# ...                                                 ...
# 4086  El programa si funciona y lo puede implementar...
# 4087  El programa no funciona, debe capturar nuevame...
# 4088  El programa no funciona, debe capturar nuevame...
# 4089  El programa si funciona y lo puede implementar...
# 4090  El programa no funciona, debe capturar nuevame...
#
#      28. Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados son verdaderos?  \
# 0                                          II solamente
# 1                                           I, II y III
# 2                                   No sé/No lo conozco
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                           II y III
# 4087                                No sé/No lo conozco
# 4088                                             I y II
# 4089                                           II y III
# 4090                                No sé/No lo conozco
#
#      27. Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?  \
# 0                                                     8
# 1                                                10 y 3
# 2                                                    10
# 3                                                10 y 3
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                 10
# 4087                                                 10
# 4088                                             10 y 3
# 4089                                                 10
# 4090                                                  3
#
#      26. Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?  \
# 0                                                     6
# 1                                                     3
# 2                                                     8
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                  6
# 4087                                                  8
# 4088                                                  2
# 4089                                                  6
# 4090                                                  3
#
#      20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:  \
# 0     Le explicaría la respuesta correcta - 6, Le su...
# 1     Le explicaría la respuesta correcta - 10, Le s...
# 2     Le explicaría la respuesta correcta - 5, Le su...
# 3     Le explicaría la respuesta correcta - 8, Le su...
# 4     Le explicaría la respuesta correcta - 5, Le su...
# ...                                                 ...
# 4086  Le explicaría la respuesta correcta - 2, Le su...
# 4087  Le explicaría la respuesta correcta - 8, Le su...
# 4088  Le explicaría la respuesta correcta - 7, Le su...
# 4089  Le explicaría la respuesta correcta - 5, Le su...
# 4090  Le explicaría la respuesta correcta - 3, Le su...
#
#      Edad  ... 11.9 El hombre está incompleto sin la mujer.  \
# 0      47  ...                                   De acuerdo
# 1      49  ...                        Totalmente de acuerdo
# 2      48  ...                     Totalmente en desacuerdo
# 3      53  ...                     Totalmente en desacuerdo
# 4      53  ...                                       Neutro
# ...   ...  ...                                          ...
# 4086   42  ...                                       Neutro
# 4087   47  ...                                       Neutro
# 4088   52  ...                        Totalmente de acuerdo
# 4089   28  ...                        Totalmente de acuerdo
# 4090   54  ...                                       Neutro
#
#      11.10 Las mujeres en comparación con los hombres tienden a tener un sentido más refinado de la cultura y el buen gusto.  \
# 0                                 Totalmente de acuerdo
# 1                                 Totalmente de acuerdo
# 2                              Totalmente en desacuerdo
# 3                                            De acuerdo
# 4                                                Neutro
# ...                                                 ...
# 4086                                      En desacuerdo
# 4087                                      En desacuerdo
# 4088                                      En desacuerdo
# 4089                                             Neutro
# 4090                                         De acuerdo
#
#      11.11 Los hombres deberían estar dispuestos a sacrificar su propio bienestar con el fin de proveer seguridad económica a las mujeres.  \
# 0                                            De acuerdo
# 1                              Totalmente en desacuerdo
# 2                              Totalmente en desacuerdo
# 3                              Totalmente en desacuerdo
# 4                                         En desacuerdo
# ...                                                 ...
# 4086                                      En desacuerdo
# 4087                           Totalmente en desacuerdo
# 4088                           Totalmente en desacuerdo
# 4089                                             Neutro
# 4090                                             Neutro
#
#      13.1 Sé cómo resolver los problemas técnicos cuando fallan las TIC  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                            De acuerdo
# 3                                                Neutro
# 4                                                Neutro
# ...                                                 ...
# 4086                                             Neutro
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                             Neutro
#
#      13.2 Puedo aprender sobre nuevas tecnologías fácilmente  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                            De acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      13.3 Sé cómo usar las TIC con los estudiantes en clase  \
# 0                                 Totalmente de acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      13.4 Me apoyo en mis colegas para resolver problemas sobre cómo trabajar algún tema  \
# 0                                 Totalmente de acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                      En desacuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      13.5 Puedo hablar con otros docentes sobre el diseño de cursos  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                            De acuerdo
# 3                                            De acuerdo
# 4                                 Totalmente de acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                             Neutro
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      13.6 Siento que tengo apoyo de otros docentes para el diseño de mis cursos  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                            De acuerdo
# 3                                            De acuerdo
# 4                                                Neutro
# ...                                                 ...
# 4086                                             Neutro
# 4087                                      En desacuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      13.7 No tengo con quién conversar sobre el diseño de mis cursos
# 0                                            De acuerdo
# 1                              Totalmente en desacuerdo
# 2                                                Neutro
# 3                                         En desacuerdo
# 4                                                Neutro
# ...                                                 ...
# 4086                                      En desacuerdo
# 4087                              Totalmente de acuerdo
# 4088                           Totalmente en desacuerdo
# 4089                           Totalmente en desacuerdo
# 4090                           Totalmente en desacuerdo
#
# [4091 rows x 62 columns]

# %%
## Pregunta 15
col = "15. Por favor evalúe las siguientes afirmaciones según qué tan de acuerdo está usted con enseñar las siguientes prácticas como objetivos de aprendizaje relacionados con el pensamiento computacional:"
df_res = pivot_inicial[col].str.split(r'\b\D+\b', expand=True)
df_res
df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)

df_res.rename({
    1: '15.1 Usar el correo electrónico',
    2: '15.2 Crear y usar de modelos y simulaciones',
    3: '15.3 Automatizar tareas',
    4: '15.4 Usar Word',
    5: '15.5 Procesar Datos',
    6: '15.6 Resolver problemas a través de herramientas computacionales (como simulaciones)',
    7: '15.7 Resolver problemas a través de herramientas computacionales (como lenguajes de programación)'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_inicial.shape)
add_columns(pivot_inicial, df_res)
print(pivot_inicial.shape)
pivot_inicial
# Out:
# (4091, 62)
# (4091, 69)
#                        Curso Identificación  \
# 0      Curso Inicial 2021 I4       19510505
# 1     Curso Inicial 2021 I28       37368988
# 2     Curso Inicial 2021 I28       88157902
# 3     Curso Inicial 2021 I64       93291177
# 4     Curso Inicial 2021 I37       98362173
# ...                      ...            ...
# 4086  Curso Inicial 2021 I26       13721233
# 4087  Curso Inicial 2021 I47       52154422
# 4088  Curso Inicial 2021 I22       71700763
# 4089  Curso Inicial 2021 I66     1065643965
# 4090  Curso Inicial 2021 I52       10274918
#
#      19. Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                                               ninguna
# 1              Excelentes las actividades desconectadas
# 2     En general se prefiere toda actividad donde el...
# 3                                      Sin comentarios.
# 4     El aprendizaje basado en proyectos es una gran...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  No conozco la estrategia de enseñanza Marcha S...
# 4088  La actividades desconectadas, promueven la int...
# 4089                                  SIN MAS QUE DECIR
# 4090  considero que la estrategia pedagógica de proy...
#
#      Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0     mas preguntas para temas de bloques y no de co...
# 1                                   Igualdad de generos
# 2     Desde hace un par de años hemos integrado el p...
# 3                                      Sin comentarios.
# 4     Hoy en día tenemos que propender por el desarr...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  Mis repuestas están basadas en el quehacer doc...
# 4088                                          Esta bien
# 4089                                  SIN MAS QUE DECIR
# 4090  al educando hay que llevarlo paso a paso en el...
#
#      25. Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?  \
# 0         El programa no funciona, falta incluir el Fin
# 1     El programa si funciona y lo puede implementar...
# 2     El programa si funciona y lo puede implementar...
# 3         El programa no funciona, falta incluir el Fin
# 4     El programa no funciona, debe capturar nuevame...
# ...                                                 ...
# 4086  El programa si funciona y lo puede implementar...
# 4087  El programa no funciona, debe capturar nuevame...
# 4088  El programa no funciona, debe capturar nuevame...
# 4089  El programa si funciona y lo puede implementar...
# 4090  El programa no funciona, debe capturar nuevame...
#
#      28. Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados son verdaderos?  \
# 0                                          II solamente
# 1                                           I, II y III
# 2                                   No sé/No lo conozco
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                           II y III
# 4087                                No sé/No lo conozco
# 4088                                             I y II
# 4089                                           II y III
# 4090                                No sé/No lo conozco
#
#      27. Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?  \
# 0                                                     8
# 1                                                10 y 3
# 2                                                    10
# 3                                                10 y 3
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                 10
# 4087                                                 10
# 4088                                             10 y 3
# 4089                                                 10
# 4090                                                  3
#
#      26. Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?  \
# 0                                                     6
# 1                                                     3
# 2                                                     8
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                  6
# 4087                                                  8
# 4088                                                  2
# 4089                                                  6
# 4090                                                  3
#
#      20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:  \
# 0     Le explicaría la respuesta correcta - 6, Le su...
# 1     Le explicaría la respuesta correcta - 10, Le s...
# 2     Le explicaría la respuesta correcta - 5, Le su...
# 3     Le explicaría la respuesta correcta - 8, Le su...
# 4     Le explicaría la respuesta correcta - 5, Le su...
# ...                                                 ...
# 4086  Le explicaría la respuesta correcta - 2, Le su...
# 4087  Le explicaría la respuesta correcta - 8, Le su...
# 4088  Le explicaría la respuesta correcta - 7, Le su...
# 4089  Le explicaría la respuesta correcta - 5, Le su...
# 4090  Le explicaría la respuesta correcta - 3, Le su...
#
#      Edad  ... 13.5 Puedo hablar con otros docentes sobre el diseño de cursos  \
# 0      47  ...                                         De acuerdo
# 1      49  ...                                         De acuerdo
# 2      48  ...                                         De acuerdo
# 3      53  ...                                         De acuerdo
# 4      53  ...                              Totalmente de acuerdo
# ...   ...  ...                                                ...
# 4086   42  ...                                         De acuerdo
# 4087   47  ...                                             Neutro
# 4088   52  ...                              Totalmente de acuerdo
# 4089   28  ...                                         De acuerdo
# 4090   54  ...                                         De acuerdo
#
#      13.6 Siento que tengo apoyo de otros docentes para el diseño de mis cursos  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                            De acuerdo
# 3                                            De acuerdo
# 4                                                Neutro
# ...                                                 ...
# 4086                                             Neutro
# 4087                                      En desacuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      13.7 No tengo con quién conversar sobre el diseño de mis cursos  \
# 0                                            De acuerdo
# 1                              Totalmente en desacuerdo
# 2                                                Neutro
# 3                                         En desacuerdo
# 4                                                Neutro
# ...                                                 ...
# 4086                                      En desacuerdo
# 4087                              Totalmente de acuerdo
# 4088                           Totalmente en desacuerdo
# 4089                           Totalmente en desacuerdo
# 4090                           Totalmente en desacuerdo
#
#      15.1 Usar el correo electrónico  \
# 0                         De acuerdo
# 1                         De acuerdo
# 2                             Neutro
# 3                         De acuerdo
# 4              Totalmente de acuerdo
# ...                              ...
# 4086                          Neutro
# 4087                      De acuerdo
# 4088                          Neutro
# 4089           Totalmente de acuerdo
# 4090           Totalmente de acuerdo
#
#      15.2 Crear y usar de modelos y simulaciones 15.3 Automatizar tareas  \
# 0                          Totalmente de acuerdo              De acuerdo
# 1                                     De acuerdo              De acuerdo
# 2                          Totalmente de acuerdo   Totalmente de acuerdo
# 3                                     De acuerdo              De acuerdo
# 4                                     De acuerdo                  Neutro
# ...                                          ...                     ...
# 4086                                  De acuerdo              De acuerdo
# 4087                       Totalmente de acuerdo              De acuerdo
# 4088                       Totalmente de acuerdo   Totalmente de acuerdo
# 4089                       Totalmente de acuerdo                  Neutro
# 4090                       Totalmente de acuerdo   Totalmente de acuerdo
#
#              15.4 Usar Word    15.5 Procesar Datos  \
# 0     Totalmente de acuerdo             De acuerdo
# 1                De acuerdo             De acuerdo
# 2                    Neutro  Totalmente de acuerdo
# 3     Totalmente de acuerdo             De acuerdo
# 4                De acuerdo             De acuerdo
# ...                     ...                    ...
# 4086                 Neutro                 Neutro
# 4087             De acuerdo             De acuerdo
# 4088                 Neutro  Totalmente de acuerdo
# 4089  Totalmente de acuerdo  Totalmente de acuerdo
# 4090                 Neutro  Totalmente de acuerdo
#
#      15.6 Resolver problemas a través de herramientas computacionales (como simulaciones)  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                                Neutro
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                              Totalmente de acuerdo
# 4088                              Totalmente de acuerdo
# 4089                              Totalmente de acuerdo
# 4090                              Totalmente de acuerdo
#
#      15.7 Resolver problemas a través de herramientas computacionales (como lenguajes de programación)
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                                Neutro
# 4                                                Neutro
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                              Totalmente de acuerdo
# 4090                              Totalmente de acuerdo
#
# [4091 rows x 69 columns]

# %%
## Pregunta 16
col = "16. Por favor evalúe los siguientes enunciados de acuerdo con qué tan preparado(a) se siente para integrar el pensamiento computacional en sus cursos:"
df_res = pivot_inicial[col].str.split(r'\b\D+\b', expand=True)
df_res

df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)

df_res.rename({
    1: '16.1 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi trabajo',
    2: '16.2 Puedo definir el pensamiento computacional',
    3: '16.3 Puedo describir las prácticas y habilidades que componen el pensamiento computacional a mis estudiantes',
    4: '16.4 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi vida diaria',
    5: '16.5 Creo que tengo las habilidades para desarrollar el pensamiento computacional en mis estudiantes',
    6: '16.6 Puedo enseñar fácilmente sobre nuevas prácticas computacionales',
    7: '16.7 Puedo diseñar una clase que desarrolle el pensamiento computacional en los estudiantes',
    8: '16.8 Puedo seleccionar tecnologías para usar en mi salón de clases, que me permitan mejorar qué enseño y cómo enseño pensamiento computacional.',
    9: '16.9 Puedo aplicar mis habilidades en pensamiento computacional para ayudar a los estudiantes a perseguir sus intereses individuales',
    10: '16.10 Puedo implementar y evaluar la idoneidad de una estrategia pedagógica que le permita a los estudiantes desarrollar pensamiento computacional'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_inicial.shape)
add_columns(pivot_inicial, df_res)
print(pivot_inicial.shape)
pivot_inicial
# Out:
# (4091, 69)
# (4091, 79)
#                        Curso Identificación  \
# 0      Curso Inicial 2021 I4       19510505
# 1     Curso Inicial 2021 I28       37368988
# 2     Curso Inicial 2021 I28       88157902
# 3     Curso Inicial 2021 I64       93291177
# 4     Curso Inicial 2021 I37       98362173
# ...                      ...            ...
# 4086  Curso Inicial 2021 I26       13721233
# 4087  Curso Inicial 2021 I47       52154422
# 4088  Curso Inicial 2021 I22       71700763
# 4089  Curso Inicial 2021 I66     1065643965
# 4090  Curso Inicial 2021 I52       10274918
#
#      19. Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                                               ninguna
# 1              Excelentes las actividades desconectadas
# 2     En general se prefiere toda actividad donde el...
# 3                                      Sin comentarios.
# 4     El aprendizaje basado en proyectos es una gran...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  No conozco la estrategia de enseñanza Marcha S...
# 4088  La actividades desconectadas, promueven la int...
# 4089                                  SIN MAS QUE DECIR
# 4090  considero que la estrategia pedagógica de proy...
#
#      Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0     mas preguntas para temas de bloques y no de co...
# 1                                   Igualdad de generos
# 2     Desde hace un par de años hemos integrado el p...
# 3                                      Sin comentarios.
# 4     Hoy en día tenemos que propender por el desarr...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  Mis repuestas están basadas en el quehacer doc...
# 4088                                          Esta bien
# 4089                                  SIN MAS QUE DECIR
# 4090  al educando hay que llevarlo paso a paso en el...
#
#      25. Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?  \
# 0         El programa no funciona, falta incluir el Fin
# 1     El programa si funciona y lo puede implementar...
# 2     El programa si funciona y lo puede implementar...
# 3         El programa no funciona, falta incluir el Fin
# 4     El programa no funciona, debe capturar nuevame...
# ...                                                 ...
# 4086  El programa si funciona y lo puede implementar...
# 4087  El programa no funciona, debe capturar nuevame...
# 4088  El programa no funciona, debe capturar nuevame...
# 4089  El programa si funciona y lo puede implementar...
# 4090  El programa no funciona, debe capturar nuevame...
#
#      28. Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados son verdaderos?  \
# 0                                          II solamente
# 1                                           I, II y III
# 2                                   No sé/No lo conozco
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                           II y III
# 4087                                No sé/No lo conozco
# 4088                                             I y II
# 4089                                           II y III
# 4090                                No sé/No lo conozco
#
#      27. Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?  \
# 0                                                     8
# 1                                                10 y 3
# 2                                                    10
# 3                                                10 y 3
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                 10
# 4087                                                 10
# 4088                                             10 y 3
# 4089                                                 10
# 4090                                                  3
#
#      26. Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?  \
# 0                                                     6
# 1                                                     3
# 2                                                     8
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                  6
# 4087                                                  8
# 4088                                                  2
# 4089                                                  6
# 4090                                                  3
#
#      20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:  \
# 0     Le explicaría la respuesta correcta - 6, Le su...
# 1     Le explicaría la respuesta correcta - 10, Le s...
# 2     Le explicaría la respuesta correcta - 5, Le su...
# 3     Le explicaría la respuesta correcta - 8, Le su...
# 4     Le explicaría la respuesta correcta - 5, Le su...
# ...                                                 ...
# 4086  Le explicaría la respuesta correcta - 2, Le su...
# 4087  Le explicaría la respuesta correcta - 8, Le su...
# 4088  Le explicaría la respuesta correcta - 7, Le su...
# 4089  Le explicaría la respuesta correcta - 5, Le su...
# 4090  Le explicaría la respuesta correcta - 3, Le su...
#
#      Edad  ...  \
# 0      47  ...
# 1      49  ...
# 2      48  ...
# 3      53  ...
# 4      53  ...
# ...   ...  ...
# 4086   42  ...
# 4087   47  ...
# 4088   52  ...
# 4089   28  ...
# 4090   54  ...
#
#      16.1 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi trabajo  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                              Totalmente de acuerdo
#
#      16.2 Puedo definir el pensamiento computacional  \
# 0                                         De acuerdo
# 1                                         De acuerdo
# 2                                         De acuerdo
# 3                                         De acuerdo
# 4                                         De acuerdo
# ...                                              ...
# 4086                                      De acuerdo
# 4087                                      De acuerdo
# 4088                           Totalmente de acuerdo
# 4089                                      De acuerdo
# 4090                           Totalmente de acuerdo
#
#      16.3 Puedo describir las prácticas y habilidades que componen el pensamiento computacional a mis estudiantes  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                            De acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      16.4 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi vida diaria  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      16.5 Creo que tengo las habilidades para desarrollar el pensamiento computacional en mis estudiantes  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      16.6 Puedo enseñar fácilmente sobre nuevas prácticas computacionales  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      16.7 Puedo diseñar una clase que desarrolle el pensamiento computacional en los estudiantes  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
#      16.8 Puedo seleccionar tecnologías para usar en mi salón de clases, que me permitan mejorar qué enseño y cómo enseño pensamiento computacional.  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                                Neutro
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                              Totalmente de acuerdo
# 4090                                         De acuerdo
#
#      16.9 Puedo aplicar mis habilidades en pensamiento computacional para ayudar a los estudiantes a perseguir sus intereses individuales  \
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                            De acuerdo
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                             Neutro
# 4090                                         De acuerdo
#
#      16.10 Puedo implementar y evaluar la idoneidad de una estrategia pedagógica que le permita a los estudiantes desarrollar pensamiento computacional
# 0                                            De acuerdo
# 1                                            De acuerdo
# 2                                 Totalmente de acuerdo
# 3                                                Neutro
# 4                                            De acuerdo
# ...                                                 ...
# 4086                                         De acuerdo
# 4087                                         De acuerdo
# 4088                              Totalmente de acuerdo
# 4089                                         De acuerdo
# 4090                                         De acuerdo
#
# [4091 rows x 79 columns]

# %%
## Pregunta 18
col = "18. En una escala de 1 a 10 (donde 10 es muy a menudo), con qué frecuencia utilizarías las siguientes prácticas pedagógicas para enseñar pensamiento computacional."
pivot_inicial[col] = pivot_inicial[col].str.replace('-1', '0')
df_res = pivot_inicial[col].str.split(r'\b\D+\b', expand=True)
df_res
df_res.rename({
    1: '18.1 Actividades desconectadas',
    2: '18.2 Usa-Modifica-Crea',
    3: '18.3 Clase magistral',
    4: '18.4 Enseñanza explícita y sin ambigüedades',
    5: '18.5 Marcha Silenciosa',
    6: '18.6 Aprendizaje basado en proyectos',
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_inicial.shape)
add_columns(pivot_inicial, df_res)
print(pivot_inicial.shape)
# Out:
# (4091, 79)
# (4091, 85)

# %%
## Pregunta 20
col = "20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:"
pivot_inicial[col] = pivot_inicial[col].str.replace('-1', '0')
df_res = pivot_inicial[col].str.split(r'\b\D+\b', expand=True)
df_res

df_res.rename({
    1: '20.1 Le explicaría la respuesta correcta',
    2: '20.2 Le sugeriría ir paso a paso por el programa simulando su ejecución',
    3: '20.3 Le diría que revise sus notas',
    4: '20.4 Le sugeriría que revise las memorias colectivas',
    5: '20.5 Le sugeriría volver a leer el problema',
    6: '20.6 Le sugeriría intentar con varios valores para evaluar el programa',
    7: '20.7 Le explicaría el problema nuevamente'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_inicial.shape)
add_columns(pivot_inicial, df_res)
print(pivot_inicial.shape)
pivot_inicial
# Out:
# (4091, 85)
# (4091, 92)
#                        Curso Identificación  \
# 0      Curso Inicial 2021 I4       19510505
# 1     Curso Inicial 2021 I28       37368988
# 2     Curso Inicial 2021 I28       88157902
# 3     Curso Inicial 2021 I64       93291177
# 4     Curso Inicial 2021 I37       98362173
# ...                      ...            ...
# 4086  Curso Inicial 2021 I26       13721233
# 4087  Curso Inicial 2021 I47       52154422
# 4088  Curso Inicial 2021 I22       71700763
# 4089  Curso Inicial 2021 I66     1065643965
# 4090  Curso Inicial 2021 I52       10274918
#
#      19. Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                                               ninguna
# 1              Excelentes las actividades desconectadas
# 2     En general se prefiere toda actividad donde el...
# 3                                      Sin comentarios.
# 4     El aprendizaje basado en proyectos es una gran...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  No conozco la estrategia de enseñanza Marcha S...
# 4088  La actividades desconectadas, promueven la int...
# 4089                                  SIN MAS QUE DECIR
# 4090  considero que la estrategia pedagógica de proy...
#
#      Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0     mas preguntas para temas de bloques y no de co...
# 1                                   Igualdad de generos
# 2     Desde hace un par de años hemos integrado el p...
# 3                                      Sin comentarios.
# 4     Hoy en día tenemos que propender por el desarr...
# ...                                                 ...
# 4086                                 No hay comentarios
# 4087  Mis repuestas están basadas en el quehacer doc...
# 4088                                          Esta bien
# 4089                                  SIN MAS QUE DECIR
# 4090  al educando hay que llevarlo paso a paso en el...
#
#      25. Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?  \
# 0         El programa no funciona, falta incluir el Fin
# 1     El programa si funciona y lo puede implementar...
# 2     El programa si funciona y lo puede implementar...
# 3         El programa no funciona, falta incluir el Fin
# 4     El programa no funciona, debe capturar nuevame...
# ...                                                 ...
# 4086  El programa si funciona y lo puede implementar...
# 4087  El programa no funciona, debe capturar nuevame...
# 4088  El programa no funciona, debe capturar nuevame...
# 4089  El programa si funciona y lo puede implementar...
# 4090  El programa no funciona, debe capturar nuevame...
#
#      28. Considera el siguiente código: Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados son verdaderos?  \
# 0                                          II solamente
# 1                                           I, II y III
# 2                                   No sé/No lo conozco
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                           II y III
# 4087                                No sé/No lo conozco
# 4088                                             I y II
# 4089                                           II y III
# 4090                                No sé/No lo conozco
#
#      27. Considera el siguiente código: Si a=3, b=8 y c=10, ¿Qué imprimirá el programa?  \
# 0                                                     8
# 1                                                10 y 3
# 2                                                    10
# 3                                                10 y 3
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                 10
# 4087                                                 10
# 4088                                             10 y 3
# 4089                                                 10
# 4090                                                  3
#
#      26. Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?  \
# 0                                                     6
# 1                                                     3
# 2                                                     8
# 3                                   No sé/No lo conozco
# 4                                   No sé/No lo conozco
# ...                                                 ...
# 4086                                                  6
# 4087                                                  8
# 4088                                                  2
# 4089                                                  6
# 4090                                                  3
#
#      20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:  \
# 0     Le explicaría la respuesta correcta - 6, Le su...
# 1     Le explicaría la respuesta correcta - 10, Le s...
# 2     Le explicaría la respuesta correcta - 5, Le su...
# 3     Le explicaría la respuesta correcta - 8, Le su...
# 4     Le explicaría la respuesta correcta - 5, Le su...
# ...                                                 ...
# 4086  Le explicaría la respuesta correcta - 2, Le su...
# 4087  Le explicaría la respuesta correcta - 8, Le su...
# 4088  Le explicaría la respuesta correcta - 7, Le su...
# 4089  Le explicaría la respuesta correcta - 5, Le su...
# 4090  Le explicaría la respuesta correcta - 3, Le su...
#
#      Edad  ... 18.4 Enseñanza explícita y sin ambigüedades  \
# 0      47  ...                                           9
# 1      49  ...                                           0
# 2      48  ...                                           5
# 3      53  ...                                           9
# 4      53  ...                                           5
# ...   ...  ...                                         ...
# 4086   42  ...                                           4
# 4087   47  ...                                           9
# 4088   52  ...                                           8
# 4089   28  ...                                           5
# 4090   54  ...                                           4
#
#      18.5 Marcha Silenciosa 18.6 Aprendizaje basado en proyectos  \
# 0                         9                                   10
# 1                        10                                   10
# 2                         4                                    9
# 3                         1                                    8
# 4                         5                                   10
# ...                     ...                                  ...
# 4086                      2                                    5
# 4087                      0                                    8
# 4088                      3                                   10
# 4089                      1                                    8
# 4090                      3                                    9
#
#      20.1 Le explicaría la respuesta correcta  \
# 0                                           6
# 1                                          10
# 2                                           5
# 3                                           8
# 4                                           5
# ...                                       ...
# 4086                                        2
# 4087                                        8
# 4088                                        7
# 4089                                        5
# 4090                                        3
#
#      20.2 Le sugeriría ir paso a paso por el programa simulando su ejecución  \
# 0                                                     8
# 1                                                    10
# 2                                                    10
# 3                                                    10
# 4                                                    10
# ...                                                 ...
# 4086                                                  9
# 4087                                                 10
# 4088                                                 10
# 4089                                                 10
# 4090                                                  6
#
#      20.3 Le diría que revise sus notas  \
# 0                                     9
# 1                                    10
# 2                                     9
# 3                                     6
# 4                                    10
# ...                                 ...
# 4086                                 10
# 4087                                 10
# 4088                                  7
# 4089                                 10
# 4090                                  4
#
#      20.4 Le sugeriría que revise las memorias colectivas  \
# 0                                                     9
# 1                                                    10
# 2                                                    10
# 3                                                     9
# 4                                                    10
# ...                                                 ...
# 4086                                                 10
# 4087                                                 10
# 4088                                                  9
# 4089                                                 10
# 4090                                                  4
#
#      20.5 Le sugeriría volver a leer el problema  \
# 0                                              9
# 1                                             10
# 2                                             10
# 3                                              9
# 4                                             10
# ...                                          ...
# 4086                                          10
# 4087                                          10
# 4088                                           9
# 4089                                          10
# 4090                                           4
#
#      20.6 Le sugeriría intentar con varios valores para evaluar el programa  \
# 0                                                     9
# 1                                                    10
# 2                                                    10
# 3                                                     9
# 4                                                     9
# ...                                                 ...
# 4086                                                  7
# 4087                                                  9
# 4088                                                  8
# 4089                                                 10
# 4090                                                  4
#
#      20.7 Le explicaría el problema nuevamente
# 0                                            9
# 1                                           10
# 2                                            8
# 3                                           10
# 4                                            3
# ...                                        ...
# 4086                                         2
# 4087                                         9
# 4088                                         9
# 4089                                         5
# 4090                                         2
#
# [4091 rows x 92 columns]

# %%
## Pregunta 22
col = "22. La docente Margarita decidió hacer que sus estudiantes de segundo de primaria utilicen los computadores del colegio para predecir el clima de una semana (temperatura, precipitaciones, y viento). Cada estudiante debe dibujar cómo se verá el clima en la ciudad en dicha semana. Margarita, creó un archivo compartido donde los estudiantes ingresarán la información. Luego tomaron las predicciones de modelos de Internet y los ingresaron en el mismo documento compartido. Durante una semana tomaron los datos reales, y luego, proyectaron en el tablero los datos predichos por los estudiantes, los del modelo de Internet, y los datos reales. Al finalizar, Margarita les mostró a los estudiantes cómo hacer un gráfico para comparar los diferentes datos.    ¿Está Margarita desarrollando el pensamiento computacional de sus estudiantes? Seleccione todas las respuestas que considere correctas."
opciones = [
    "No, solo está usando computadores",
    "No, los estudiantes sólo están aprendiendo a cargar cosas en un archivo compartido y crear un gráfico",
    "Si, los estudiantes están aprendiendo sobre modelos computacionales para la predicción del clima",
    "Si, los estudiantes están aprendiendo a recolectar, organizar, y analizar datos.",
    "Otra:"
]
print(pivot_inicial.shape)

divide_question_YES_NO(22, col, opciones, pivot_inicial)
pivot_inicial.drop(columns=col, inplace=True)
print(pivot_inicial.shape)
# Out:
# (4091, 92)
# 22 0
# 22 1
# 22 2
# 22 3
# 22 4
# (4091, 96)

# %%
## Pregunta 23
col = "23. La cafetería del colegio empacó almuerzos iguales para todos los estudiantes, menos los de Juan Arias y María Vásquez que no pueden comer huevo. Los almuerzos están marcados con el apellido de los estudiantes y organizados alfabéticamente. Para verificar que su almuerzo cumple con la restricción alimenticia María con ayuda de su profesor buscan en las cajas. María sabe que su almuerzo debe estar al final, así que busca hasta que encuentre una caja que comience por una letra cerca de la V. Cuando encuentra una que comienza con Trujillo, mira el último almuerzo de esa caja y se da cuenta que termina en Zapata. Así, María se da cuenta que su almuerzo debe estar allí.  ¿Está María usando el pensamiento computacional para encontrar su almuerzo? Seleccione todas las respuestas que considere correctas."

opciones = [
    "No, en ningún momento de habla de computadores",
    "Si, María está dividiendo el problema en problemas más sencillos",
    "Si, María está usando un algoritmo para encontrar su almuerzo",
    "No, María solo está buscando su almuerzo",
    "Otra:"
]
print(pivot_inicial.shape)

divide_question_YES_NO(23, col, opciones, pivot_inicial)
pivot_inicial.drop(columns=col, inplace=True)
print(pivot_inicial.shape)
# Out:
# (4091, 96)
# 23 0
# 23 1
# 23 2
# 23 3
# 23 4
# (4091, 100)

# %%
## Edad por rangos
pivot_inicial.loc[pivot_inicial['Edad'] == "-------", 'Edad'] = "46"
pivot_inicial['Edad'] = pivot_inicial['Edad'].str.strip().str.slice(stop=2).str.strip().fillna(46).astype(int)
criteria = [
    pivot_inicial['Edad'].between(16, 20), 
    pivot_inicial['Edad'].between(21, 24), 
    pivot_inicial['Edad'].between(25, 34), 
    pivot_inicial['Edad'].between(35, 44), 
    pivot_inicial['Edad'].between(45, 80)]

values = ["16-20","21-24","25-34","35-44","45+"]

pivot_inicial['Edad'] = np.select(criteria, values, 0)
pivot_inicial['Edad']
# Out:
# 0         45+
# 1         45+
# 2         45+
# 3         45+
# 4         45+
#         ...
# 4086    35-44
# 4087      45+
# 4088      45+
# 4089    25-34
# 4090      45+
# Name: Edad, Length: 4091, dtype: object

# %%
## Borrar preguntas que tiene subpreguntas pero que no debe estar la pregunta
# 9, 11, 13, 15, 16, 18, 20
borrar_ini = [
    "9. ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)",
    "11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:",
    "13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:",
    "15. Por favor evalúe las siguientes afirmaciones según qué tan de acuerdo está usted con enseñar las siguientes prácticas como objetivos de aprendizaje relacionados con el pensamiento computacional:",
    "16. Por favor evalúe los siguientes enunciados de acuerdo con qué tan preparado(a) se siente para integrar el pensamiento computacional en sus cursos:",
    "18. En una escala de 1 a 10 (donde 10 es muy a menudo), con qué frecuencia utilizarías las siguientes prácticas pedagógicas para enseñar pensamiento computacional.",
    "20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:"
]

pivot_inicial.drop(columns=borrar_ini, inplace=True)

# %%
#pivot_inicial[col][pivot_inicial[col].str.len().argmax()]
pivot_inicial
pivot_inicial.to_excel('posttest_inicial_v3.xlsx', index=False, encoding='utf-8-sig')

# %%
print("\\o/\n"*10)
# Out:
# \o/
# \o/
# \o/
# \o/
# \o/
# \o/
# \o/
# \o/
# \o/
# \o/

# %% [markdown]
# ### Limpieza por pregunta POSTTEST AVANZADO

# %%
avanzado = {
    '¿Cuál es su estrato socioeconómico?': 'Estrato',

    'La contaminación en las principales ciudades del país es algo que preocupa a los gobernantes. Las concentraciones de contaminantes se miden con un valor llamado el Índice de Calidad del Aire (ICA). La siguiente tabla muestra los valores para los cuales el ICA representa una calidad del aire Buena, Regular, Mala, y Muy Mala.    Como el programa que creó Nicolás mostró que el aire en el centro de la ciudad estaba muy contaminado en ciertos momentos, el alcalde decidió tomar medidas extremas. Revisa el siguiente programa y elije la opción que describe la medida que tomó el alcalde': '22. La contaminación en las principales ciudades del país es algo que preocupa a los gobernantes. Las concentraciones de contaminantes se miden con un valor llamado el Índice de Calidad del Aire (ICA). La siguiente tabla muestra los valores para los cuales el ICA representa una calidad del aire Buena, Regular, Mala, y Muy Mala.    Como el programa que creó Nicolás mostró que el aire en el centro de la ciudad estaba muy contaminado en ciertos momentos, el alcalde decidió tomar medidas extremas. Revisa el siguiente programa y elije la opción que describe la medida que tomó el alcalde',

    'Dada la definición de la función:¿Cuál de las siguientes afirmaciones describe mejor el llamado a la función sumar (8, 5, 12)?': '23. Dada la definición de la función:¿Cuál de las siguientes afirmaciones describe mejor el llamado a la función sumar (8, 5, 12)?',

    'Considera el siguiente segmento de código:Seleccione el fragmento de código más correcto que resultará en el cálculo del área de la superficie de un cilindro, dada la fórmula:': '24. Considera el siguiente segmento de código:Seleccione el fragmento de código más correcto que resultará en el cálculo del área de la superficie de un cilindro, dada la fórmula:',

    'Considera el siguiente segmento de código: ¿En qué orden deberá realizar las siguientes operaciones de manera que el valor de la variable “a” sea 15 al finalizar?': '25. Considera el siguiente segmento de código: ¿En qué orden deberá realizar las siguientes operaciones de manera que el valor de la variable “a” sea 15 al finalizar?',

    'Tim examina cada una de las siguientes piezas de código y responde que la primera termina con X siendo igual a 5, y la segunda con X siendo igual a 16.¿Cuál es el error conceptual de Tim?': '26. Tim examina cada una de las siguientes piezas de código y responde que la primera termina con X siendo igual a 5, y la segunda con X siendo igual a 16.¿Cuál es el error conceptual de Tim?',

    'María vive cerca de una montaña donde hace mucho calor en el día, pero mucho frío en la noche. Ella tiene calefacción y aire acondicionado en su apartamento, pero deben prenderlo desde la portería que está en el primer piso del edificio. María decidió     programar la Micro:bit para que envíe un mensaje de encender la calefacción cuando esté frío (menos de 15 grados) y encender el aire acondicionado cuando esté caliente (más de 25 grados). ¿Cuál de los siguientes programas le podríafuncionar a María?                						Imagen 1              						                   						Imagen 2           	                                                                 Imagen 3           	                                                         Imagen 4': '27. María vive cerca de una montaña donde hace mucho calor en el día, pero mucho frío en la noche. Ella tiene calefacción y aire acondicionado en su apartamento, pero deben prenderlo desde la portería que está en el primer piso del edificio. María decidió     programar la Micro:bit para que envíe un mensaje de encender la calefacción cuando esté frío (menos de 15 grados) y encender el aire acondicionado cuando esté caliente (más de 25 grados). ¿Cuál de los siguientes programas le podríafuncionar a María?                						Imagen 1              						                   						Imagen 2           	                                                                 Imagen 3           	                                                         Imagen 4',

    'Juan y Andrea crearon un juego en la Micro:bit y lo compartieron con sus compañeros. Sin embargo, nadie parece entender de qué se trata.': '28. Juan y Andrea crearon un juego en la Micro:bit y lo compartieron con sus compañeros. Sin embargo, nadie parece entender de qué se trata.',

    '¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?': '29. ¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?',

    'La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.                                            Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria? Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                             Imagen 1                                                                      Imagen 2                                                                                      Imagen 3                                                                      Imagen 4': '30. La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.                                            Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria? Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                             Imagen 1                                                                      Imagen 2                                                                                      Imagen 3                                                                      Imagen 4',


}

# %%
pivot_avanzado.rename(columns=compartidas, inplace=True)
pivot_avanzado.rename(columns=avanzado, inplace=True)
pivot_avanzado.to_excel('pivot_avanzado_renamed.xlsx', index=False, encoding='utf-8-sig')

# %%
## Pregunta 9
col = "9. ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)"
pivot_avanzado[col] = pivot_avanzado[col].str.replace('-1', '0')
df_res = pivot_avanzado[col].str.split(r'\b\D+\b', expand=True)
df_res.rename({
    1: '9.1 Ciencias naturales y educación ambiental',
    2: '9.2 Ciencias sociales, historia, geografía, constitución política y democracia',
    3: '9.3 Educación artística',
    4: '9.4 Educación ética y en valores humanos',
    5: '9.5 Educación física, recreación y deportes',
    6: '9.6 Educación religiosa',
    7: '9.7 Humanidades, lengua castellana e idiomas extranjeros',
    8: '9.8 Matemáticas',
    9: '9.9 Tecnología e informática',
    10: '9.10 Otro'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_avanzado.shape)
add_columns(pivot_avanzado, df_res)
print(pivot_avanzado.shape)
# Out:
# (796, 31)
# (796, 41)

# %%
## Pregunta 10
col = "10. ¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)"

"'1.\t, 2.\t, 3.\t, 4.\t, 5.\t'"

opciones = [
    "Promover actividades que no perpetúen estereotipos de género, por ejemplo, que las niñas y adolescentes jueguen a la construcción y ensamble.",
    "Realizar clubes y actividades extracurriculares para niñas y jóvenes como refuerzo de lo visto en las clases de áreas STEM.",
    "Destacar y reconocer los logros de las niñas y jóvenes, por ejemplo, promover concursos diferenciados por género, como, premio a la niña científica y el niño científico.",
    "Dedicar una clase exclusiva a reflexionar sobre el género, por ejemplo, con una película, una lectura o una conversación, etc…",
    "Dar referencias o modelos de mujeres destacadas en las áreas STEM, por ejemplo, mostrar la película de Marie Curie."
]
print(pivot_avanzado.shape)

divide_question_YES_NO(10, col, opciones, pivot_avanzado)
pivot_avanzado.drop(columns=col, inplace=True)
print(pivot_avanzado.shape)
# Out:
# (796, 41)
# 10 0
# 10 1
# 10 2
# 10 3
# 10 4
# (796, 45)

# %%
## Pregunta 11
col = "11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:"
df_res = pivot_avanzado[col].str.split(r'\b\D+\b', expand=True)
df_res

' - 2,  - 2,  - 2,  - 4,  - 2,  - 4,  - 5,  - 5,  - 5,  - 4,  - 4'

df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)
df_res.rename({
    1: '11.1 Es preferible que las mujeres enseñen ciencias sociales y los hombres ciencias exactas.',
    2: '11.2 Es necesario que haya igual número de mujeres ganadoras del nobel de física como hombres.',
    3: '11.3 Es normal que la mayoría de los ingenieros mecánicos sean varones porque los hombres son mejores para los números.',
    4: '11.4 Las becas en áreas STEM que son sólo para mujeres discriminan a los hombres y generan desigualdad.',
    5: '11.5 Que haya más físicos que físicas se explica por una historia de dominación masculina',
    6: '11.6 Muchas mujeres se caracterizan por una pureza que pocos hombres poseen.',
    7: '11.7 Las mujeres deben ser queridas y protegidas por los hombres.',
    8: '11.8 Todo hombre debe tener una mujer a quien amar.',
    9: '11.9 El hombre está incompleto sin la mujer.',
    10: '11.10 Las mujeres en comparación con los hombres tienden a tener un sentido más refinado de la cultura y el buen gusto.',
    11: '11.11 Los hombres deberían estar dispuestos a sacrificar su propio bienestar con el fin de proveer seguridad económica a las mujeres.'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)

print(pivot_avanzado.shape)
add_columns(pivot_avanzado, df_res)
print(pivot_avanzado.shape)
# Out:
# (796, 45)
# (796, 56)

# %%
## Pregunta 13
col = "13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:"
df_res = pivot_avanzado[col].str.split(r'\b\D+\b', expand=True)
df_res
df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)

df_res.rename({
    1: '13.1 Sé cómo resolver los problemas técnicos cuando fallan las TIC',
    2: '13.2 Puedo aprender sobre nuevas tecnologías fácilmente',
    3: '13.3 Sé cómo usar las TIC con los estudiantes en clase',
    4: '13.4 Me apoyo en mis colegas para resolver problemas sobre cómo trabajar algún tema',
    5: '13.5 Puedo hablar con otros docentes sobre el diseño de cursos',
    6: '13.6 Siento que tengo apoyo de otros docentes para el diseño de mis cursos',
    7: '13.7 No tengo con quién conversar sobre el diseño de mis cursos'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_avanzado.shape)
add_columns(pivot_avanzado, df_res)
print(pivot_avanzado.shape)
# Out:
# (796, 56)
# (796, 63)

# %%
## Pregunta 15
col = "15. Por favor evalúe las siguientes afirmaciones según qué tan de acuerdo está usted con enseñar las siguientes prácticas como objetivos de aprendizaje relacionados con el pensamiento computacional:"
df_res = pivot_avanzado[col].str.split(r'\b\D+\b', expand=True)
df_res
df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)

df_res.rename({
    1: '15.1 Usar el correo electrónico',
    2: '15.2 Crear y usar de modelos y simulaciones',
    3: '15.3 Automatizar tareas',
    4: '15.4 Usar Word',
    5: '15.5 Procesar Datos',
    6: '15.6 Resolver problemas a través de herramientas computacionales (como simulaciones)',
    7: '15.7 Resolver problemas a través de herramientas computacionales (como lenguajes de programación)'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_avanzado.shape)
add_columns(pivot_avanzado, df_res)
print(pivot_avanzado.shape)
# Out:
# (796, 63)
# (796, 70)

# %%
## Pregunta 16
col = "16. Por favor evalúe los siguientes enunciados de acuerdo con qué tan preparado(a) se siente para integrar el pensamiento computacional en sus cursos:"
df_res = pivot_avanzado[col].str.split(r'\b\D+\b', expand=True)
df_res

df_res.iloc[:, 1:] = df_res.iloc[:, 1:].astype(int).replace(de_acuerdo)

df_res.rename({
    1: '16.1 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi trabajo',
    2: '16.2 Puedo definir el pensamiento computacional',
    3: '16.3 Puedo describir las prácticas y habilidades que componen el pensamiento computacional a mis estudiantes',
    4: '16.4 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi vida diaria',
    5: '16.5 Creo que tengo las habilidades para desarrollar el pensamiento computacional en mis estudiantes',
    6: '16.6 Puedo enseñar fácilmente sobre nuevas prácticas computacionales',
    7: '16.7 Puedo diseñar una clase que desarrolle el pensamiento computacional en los estudiantes',
    8: '16.8 Puedo seleccionar tecnologías para usar en mi salón de clases, que me permitan mejorar qué enseño y cómo enseño pensamiento computacional.',
    9: '16.9 Puedo aplicar mis habilidades en pensamiento computacional para ayudar a los estudiantes a perseguir sus intereses individuales',
    10: '16.10 Puedo implementar y evaluar la idoneidad de una estrategia pedagógica que le permita a los estudiantes desarrollar pensamiento computacional'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_avanzado.shape)
add_columns(pivot_avanzado, df_res)
print(pivot_avanzado.shape)
# Out:
# (796, 70)
# (796, 80)

# %%
## Pregunta 18
col = "18. En una escala de 1 a 10 (donde 10 es muy a menudo), con qué frecuencia utilizarías las siguientes prácticas pedagógicas para enseñar pensamiento computacional."
pivot_avanzado[col] = pivot_avanzado[col].str.replace('-1', '0')
df_res = pivot_avanzado[col].str.split(r'\b\D+\b', expand=True)
df_res
df_res.rename({
    1: '18.1 Actividades desconectadas',
    2: '18.2 Usa-Modifica-Crea',
    3: '18.3 Clase magistral',
    4: '18.4 Enseñanza explícita y sin ambigüedades',
    5: '18.5 Marcha Silenciosa',
    6: '18.6 Aprendizaje basado en proyectos',
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_avanzado.shape)
add_columns(pivot_avanzado, df_res)
print(pivot_avanzado.shape)
# Out:
# (796, 80)
# (796, 86)

# %%
## Pregunta 20
col = "20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:"
pivot_avanzado[col] = pivot_avanzado[col].str.replace('-1', '0')
df_res = pivot_avanzado[col].str.split(r'\b\D+\b', expand=True)
df_res

df_res.rename({
    1: '20.1 Le explicaría la respuesta correcta',
    2: '20.2 Le sugeriría ir paso a paso por el programa simulando su ejecución',
    3: '20.3 Le diría que revise sus notas',
    4: '20.4 Le sugeriría que revise las memorias colectivas',
    5: '20.5 Le sugeriría volver a leer el problema',
    6: '20.6 Le sugeriría intentar con varios valores para evaluar el programa',
    7: '20.7 Le explicaría el problema nuevamente'
}, axis=1, inplace=True)
df_res.drop([0], axis=1, inplace=True)
print(pivot_avanzado.shape)
add_columns(pivot_avanzado, df_res)
print(pivot_avanzado.shape)
# Out:
# (796, 86)
# (796, 93)

# %%
## Edad por rangos
pivot_avanzado['Edad'] = pivot_avanzado['Edad'].str.strip().str.slice(stop=2).str.strip().fillna(46).astype(int)
criteria = [
    pivot_avanzado['Edad'].between(16, 20), 
    pivot_avanzado['Edad'].between(21, 24), 
    pivot_avanzado['Edad'].between(25, 34), 
    pivot_avanzado['Edad'].between(35, 44), 
    pivot_avanzado['Edad'].between(45, 80)]

values = ["16-20","21-24","25-34","35-44","45+"]

pivot_avanzado['Edad'] = np.select(criteria, values, 0)
pivot_avanzado['Edad']
# Out:
# 0      35-44
# 1      25-34
# 2        45+
# 3        45+
# 4        45+
#        ...
# 791      45+
# 792    35-44
# 793    25-34
# 794    35-44
# 795      45+
# Name: Edad, Length: 796, dtype: object

# %%
## Borrar preguntas que tiene subpreguntas pero que no debe estar la pregunta
# 9, 11, 13, 15, 16, 18, 20
borrar_av = [
    "9. ¿Cuáles de las siguientes áreas enseña y en qué grado? (Marque 'NS/NC' si no enseña el área)",
    "11. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:",
    "13. Por favor evalúe los siguientes enunciados de acuerdo con su experiencia:",
    "15. Por favor evalúe las siguientes afirmaciones según qué tan de acuerdo está usted con enseñar las siguientes prácticas como objetivos de aprendizaje relacionados con el pensamiento computacional:",
    "16. Por favor evalúe los siguientes enunciados de acuerdo con qué tan preparado(a) se siente para integrar el pensamiento computacional en sus cursos:",
    "18. En una escala de 1 a 10 (donde 10 es muy a menudo), con qué frecuencia utilizarías las siguientes prácticas pedagógicas para enseñar pensamiento computacional.",
    "20. Cuando un estudiante se enfrenta a una dificultad creando un programa y no sabe si está correcto, qué tan a menudo, en una escala de 1-10 (donde 10 es siempre), usted:"
]

pivot_avanzado.drop(columns=borrar_av, inplace=True)

# %%
pivot_avanzado.to_excel('posttest_avanzado_v3.xlsx', index=False, encoding='utf-8-sig')

# %%
pivot_avanzado
# Out:
#                        Curso Identificación  \
# 0    Curso Avanzado 2021 A10       86067286
# 1    Curso Avanzado 2021 A24     1048690074
# 2    Curso Avanzado 2021 A19       93204985
# 3    Curso Avanzado 2021 A30       52012944
# 4     Curso Avanzado 2021 A4       78731135
# ..                       ...            ...
# 791  Curso Avanzado 2021 A24       13054101
# 792   Curso Avanzado 2021 A4       16459296
# 793  Curso Avanzado 2021 A12     1077428368
# 794   Curso Avanzado 2021 A3       52761755
# 795  Curso Avanzado 2021 A20       30324088
#
#     30. La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.                                            Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria? Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                             Imagen 1                                                                      Imagen 2                                                                                      Imagen 3                                                                      Imagen 4  \
# 0                                             Imagen 2
# 1                                             Imagen 3
# 2                                             Imagen 2
# 3                                             Imagen 2
# 4                                             Imagen 3
# ..                                                 ...
# 791                                           Imagen 3
# 792                                           Imagen 3
# 793                                           Imagen 4
# 794                                           Imagen 3
# 795                                           Imagen 3
#
#     27. María vive cerca de una montaña donde hace mucho calor en el día, pero mucho frío en la noche. Ella tiene calefacción y aire acondicionado en su apartamento, pero deben prenderlo desde la portería que está en el primer piso del edificio. María decidió     programar la Micro:bit para que envíe un mensaje de encender la calefacción cuando esté frío (menos de 15 grados) y encender el aire acondicionado cuando esté caliente (más de 25 grados). ¿Cuál de los siguientes programas le podríafuncionar a María?                \t\t\t\t\t\tImagen 1              \t\t\t\t\t\t                   \t\t\t\t\t\tImagen 2           \t                                                                 Imagen 3           \t                                                         Imagen 4  \
# 0                                             Imagen 3
# 1                                             Imagen 4
# 2                                             Imagen 3
# 3                                             Imagen 3
# 4                                             Imagen 3
# ..                                                 ...
# 791                                           Imagen 3
# 792                                           Imagen 3
# 793                                           Imagen 4
# 794                                           Imagen 3
# 795                                           Imagen 3
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0                                                  NaN
# 1                                           Capacitado
# 2    Desarrollar el pensamiento computacional es mu...
# 3                                    Ningún comentario
# 4    resalto el trabajo de las alumnas he tenido es...
# ..                                                 ...
# 791  A pesar que el Rector, no desea contratar serv...
# 792                                                NaN
# 793  Cuando somo capacitados esto nos lleva a capac...
# 794                                          No aplica
# 795  El desarrollo del pensamiento computacional pu...
#
#     19. Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.  \
# 0                     Agregaria mas trabajo individual
# 1                                              Mejorar
# 2              Practicas con actividades desconectadas
# 3                                    Ningún comentario
# 4    el aprendizaje basado en proyectos permite al ...
# ..                                                 ...
# 791   Abp, esta enproceso de implementacion en la I.E.
# 792                                                NaN
# 793                            Poco a poco se avanza .
# 794                                          No aplica
# 795  Las actividades dependen de los diferentes con...
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                    Ningún comentario
# 4    la idea es que al programar se pongan aprueba ...
# ..                                                 ...
# 791  En la imagen 3, cuando el nivel de luz sea 100...
# 792  Son aburridoras y repetidas, las respondí como...
# 793       Felicitaciones por este maravilloso trabajo.
# 794         sería bueno condicionar también el horario
# 795  Es sencillo ahora que he trabajado con la micr...
#
#     Agrega cualquier comentario o clarificación sobre las preguntas anteriores.  \
# 0    El ejemplo es la mejor forma de enseñar, mostr...
# 1                                         Compañerismo
# 2    Las mujeres tienen los mismos derechos de los ...
# 3                                    Ningún comentario
# 4                                          la igualdad
# ..                                                 ...
# 791  lo agradable sel error, es que te replantea re...
# 792                                                NaN
# 793  Estamos en el tiempo que toda persona hace uso...
# 794         Se requiere promover la igualdad de género
# 795  La igualdad debe ser tratada con tacto, porque...
#
#     25. Considera el siguiente segmento de código: ¿En qué orden deberá realizar las siguientes operaciones de manera que el valor de la variable “a” sea 15 al finalizar?  \
# 0                           delta, épsilon, alfa, gama
# 1                                  No sé/No lo conozco
# 2                           delta, épsilon, alfa, gama
# 3                           delta, épsilon, alfa, gama
# 4                     beta, épsilon, gama, delta, alfa
# ..                                                 ...
# 791                   alfa, delta, gama, beta, épsilon
# 792                                No sé/No lo conozco
# 793                   épsilon, delta, beta, gama, alfa
# 794                   épsilon, delta, beta, gama, alfa
# 795                   beta, épsilon, gama, delta, alfa
#
#     24. Considera el siguiente segmento de código:Seleccione el fragmento de código más correcto que resultará en el cálculo del área de la superficie de un cilindro, dada la fórmula:  \
# 0    x ::2 * 3.14 * r * r →     y ::h * x → areaSup...
# 1                                  No sé/No lo conozco
# 2    x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 3                                  No sé/No lo conozco
# 4    x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# ..                                                 ...
# 791  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 792                                No sé/No lo conozco
# 793  x ::2 * 3.14 * r * r →     y ::h * x → areaSup...
# 794  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
# 795  x ::2 → y ::x * 3.14 * r * r → z ::x * 3.14 * ...
#
#      ... 18.4 Enseñanza explícita y sin ambigüedades 18.5 Marcha Silenciosa  \
# 0    ...                                           7                      8
# 1    ...                                           7                      1
# 2    ...                                          10                      9
# 3    ...                                           6                      5
# 4    ...                                           7                      9
# ..   ...                                         ...                    ...
# 791  ...                                           7                      1
# 792  ...                                           8                      6
# 793  ...                                           9                      7
# 794  ...                                           5                      5
# 795  ...                                          10                      8
#
#     18.6 Aprendizaje basado en proyectos  \
# 0                                     10
# 1                                      6
# 2                                      4
# 3                                     10
# 4                                     10
# ..                                   ...
# 791                                    6
# 792                                    9
# 793                                    8
# 794                                    8
# 795                                    8
#
#     20.1 Le explicaría la respuesta correcta  \
# 0                                          7
# 1                                          4
# 2                                          0
# 3                                          6
# 4                                         10
# ..                                       ...
# 791                                        5
# 792                                        4
# 793                                        6
# 794                                        7
# 795                                        1
#
#     20.2 Le sugeriría ir paso a paso por el programa simulando su ejecución  \
# 0                                                    9
# 1                                                    7
# 2                                                   10
# 3                                                   10
# 4                                                   10
# ..                                                 ...
# 791                                                  9
# 792                                                  9
# 793                                                  8
# 794                                                 10
# 795                                                  8
#
#     20.3 Le diría que revise sus notas  \
# 0                                    6
# 1                                    7
# 2                                   10
# 3                                    8
# 4                                    8
# ..                                 ...
# 791                                  9
# 792                                  8
# 793                                  8
# 794                                  9
# 795                                  5
#
#     20.4 Le sugeriría que revise las memorias colectivas  \
# 0                                                    9
# 1                                                    6
# 2                                                   10
# 3                                                    9
# 4                                                    5
# ..                                                 ...
# 791                                                  9
# 792                                                  8
# 793                                                  8
# 794                                                  9
# 795                                                  7
#
#     20.5 Le sugeriría volver a leer el problema  \
# 0                                            10
# 1                                             7
# 2                                            10
# 3                                            10
# 4                                             5
# ..                                          ...
# 791                                           9
# 792                                           9
# 793                                           8
# 794                                           9
# 795                                           7
#
#     20.6 Le sugeriría intentar con varios valores para evaluar el programa  \
# 0                                                    8
# 1                                                    8
# 2                                                   10
# 3                                                   10
# 4                                                    5
# ..                                                 ...
# 791                                                  9
# 792                                                  9
# 793                                                  8
# 794                                                 10
# 795                                                  6
#
#     20.7 Le explicaría el problema nuevamente
# 0                                           8
# 1                                           5
# 2                                          10
# 3                                          10
# 4                                          10
# ..                                        ...
# 791                                         9
# 792                                         9
# 793                                         9
# 794                                        10
# 795                                         9
#
# [796 rows x 86 columns]
