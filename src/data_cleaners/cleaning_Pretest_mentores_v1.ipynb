# %%
import pandas as pd
import numpy as np

# %%
df_mentores = pd.read_excel('../../data/crudos/Pretest_mentores_v1.xlsx')

# %%
rename_cols = {
    'Número De Identificación': 'Identificación',
    "¿Hace parte de alguno de los siguientes grupos étnicos?": "Grupo Étnico",
    "Edad (años)": "Edad",
    "Género:": "Género",
    "Su institución está en un contexto:": "Contexto IE",
    "¿Cuál es su estrato socioeconómico?": "Estrato",
    'Ciencias naturales y educación ambiental.': '9.1 Ciencias naturales y educación ambiental',
    'Ciencias sociales, historia, geografía, constitución política y democracia.':'9.2 Ciencias sociales, historia, geografía, constitución política y democracia',
    'Educación artística.':'9.3 Educación artística',
    'Educación ética y en valores humanos.':'9.4 Educación ética y en valores humanos',
    'Educación física, recreación y deportes.':'9.5 Educación física, recreación y deportes',
    'Educación religiosa.':'9.6 Educación religiosa',
    'Humanidades, lengua castellana e idiomas extranjeros.':'9.7 Humanidades, lengua castellana e idiomas extranjeros',
    'Matemáticas.':'9.8 Matemáticas',
    'Tecnología e informática.':'9.9 Tecnología e informática',
    'Otro':'9.10 Otro',
    '1. Promover actividades que no perpetúen estereotipos de género, por ejemplo, que las niñas y adolescentes jueguen a la construcción y ensamble.': '10.1 Promover actividades que no perpetúen estereotipos de género, por ejemplo, que las niñas y adolescentes jueguen a la construcción y ensamble.',
    '2. Realizar clubes y actividades extracurriculares para niñas y jóvenes como refuerzo de lo visto en las clases de áreas STEM.': '10.2 Realizar clubes y actividades extracurriculares para niñas y jóvenes como refuerzo de lo visto en las clases de áreas STEM.',
    '3. Destacar y reconocer los logros de las niñas y jóvenes, por ejemplo, promover concursos diferenciados por género, como, premio a la niña científica y el niño científico.': '10.3 Destacar y reconocer los logros de las niñas y jóvenes, por ejemplo, promover concursos diferenciados por género, como, premio a la niña científica y el niño científico.',
    '4. Dedicar una clase exclusiva a reflexionar sobre el género, por ejemplo, con una película, una lectura o una conversación, etc…': '10.4 Dedicar una clase exclusiva a reflexionar sobre el género, por ejemplo, con una película, una lectura o una conversación, etc',
    '5. Dar referencias o modelos de mujeres destacadas en las áreas STEM, por ejemplo, mostrar la película de Marie Curie.': '10.5 Dar referencias o modelos de mujeres destacadas en las áreas STEM, por ejemplo, mostrar la película de Marie Curie.',
    '23.5 !other=Otra:': '23.5 Otra',
    '¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?': '29. ¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?',
    '¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?':'33. ¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?',
}

borrar_cols = [
    'Nombre',
    'Apellido',
    'Correo Electrónico',
    'Encuesta',
    'Hora',
    'Curso',
    'Agrega cualquier comentario o clarificación adicional sobre las estrategias de enseñanza de la pregunta anterior.',
    'Agrega cualquier comentario o clarificación sobre las preguntas anteriores.',
    'Agrega cualquier comentario o clarificación sobre las preguntas anteriores',
    'Agrega cualquier comentario o clarificación sobre las preguntas anteriores..1',
    '¿Cuáles de las siguientes estrategias usted ha usado en sus clases? (Selección múltiple con múltiple respuesta)',
]

df_mentores = df_mentores.drop(columns=borrar_cols, errors='ignore')
df_mentores.rename(rename_cols, axis=1, inplace=True)
df_mentores
# Out:
#      Identificación ¿Es usted cabeza de hogar? ¿Es usted líder comunitario?  \
# 0          38212096                         NO                           SI
# 1          87063860                         NO                           SI
# 2          27094245                         SI                           SI
# 3          25875830                         NO                           SI
# 4          67028072                         SI                           SI
# ..              ...                        ...                          ...
# 113        87068357                         SI                           SI
# 114        16695898                         SI                           SI
# 115      1022944647                         NO                           SI
# 116        80034893                         SI                           SI
# 117      1085269046                         NO                           SI
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# Ahora, reemplazar las respuestas de algunas preguntas

# %%
cols9 = ['9.1 Ciencias naturales y educación ambiental',
 '9.2 Ciencias sociales, historia, geografía, constitución política y democracia',
 '9.9 Tecnología e informática',
 '9.3 Educación artística',
 '9.4 Educación ética y en valores humanos',
 '9.5 Educación física, recreación y deportes',
 '9.6 Educación religiosa',
 '9.7 Humanidades, lengua castellana e idiomas extranjeros',
 '9.8 Matemáticas',
 '9.10 Otro']

replace_cols9 = {'-1': 0, '-': 0, np.nan: 0, 'nan': 0}

df_mentores.loc[:, cols9] = df_mentores.loc[:, cols9].astype(str).replace(replace_cols9).astype(int)
df_mentores.loc[:, cols9]
# Out:
#      9.1 Ciencias naturales y educación ambiental  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ..                                            ...
# 113                                             0
# 114                                             0
# 115                                             0
# 116                                             0
# 117                                             0
#
#      9.2 Ciencias sociales, historia, geografía, constitución política y democracia  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# ...

# %%
#
compartidas = [
    'Identificación', 
    'Edad',
    'Género',
    'Estrato',
    'Contexto IE',
    'Grupo Étnico',
    '¿Es usted cabeza de hogar?',
    '¿Es usted líder comunitario?',
    '9.1 Ciencias naturales y educación ambiental',
    '9.2 Ciencias sociales, historia, geografía, constitución política y democracia',
    '9.3 Educación artística',
    '9.4 Educación ética y en valores humanos',
    '9.5 Educación física, recreación y deportes',
    '9.6 Educación religiosa',
    '9.7 Humanidades, lengua castellana e idiomas extranjeros',
    '9.8 Matemáticas',
    '9.9 Tecnología e informática',
    '9.10 Otro', 
]

# %%
#

genero_si = ['10.1 Promover actividades que no perpetúen estereotipos de género, por ejemplo, que las niñas y adolescentes jueguen a la construcción y ensamble.',
 '10.2 Realizar clubes y actividades extracurriculares para niñas y jóvenes como refuerzo de lo visto en las clases de áreas STEM.',
 '10.3 Destacar y reconocer los logros de las niñas y jóvenes, por ejemplo, promover concursos diferenciados por género, como, premio a la niña científica y el niño científico.',
 '10.4 Dedicar una clase exclusiva a reflexionar sobre el género, por ejemplo, con una película, una lectura o una conversación, etc',
 '10.5 Dar referencias o modelos de mujeres destacadas en las áreas STEM, por ejemplo, mostrar la película de Marie Curie.',
            ]

df_mentores[genero_si]
# Out:
#     10.1 Promover actividades que no perpetúen estereotipos de género, por ejemplo, que las niñas y adolescentes jueguen a la construcción y ensamble.  \
# 0                                                   NO
# 1                                                   SI
# 2                                                   SI
# 3                                                   NO
# 4                                                   SI
# ..                                                 ...
# 113                                                 NO
# 114                                                 SI
# 115                                                 SI
# 116                                                 NO
# 117                                                 SI
#
#     10.2 Realizar clubes y actividades extracurriculares para niñas y jóvenes como refuerzo de lo visto en las clases de áreas STEM.  \
# 0                                                   NO
# ...

# %%
#
genero_acuerdo = ['11.1 Es preferible que las mujeres enseñen ciencias sociales y los hombres ciencias exactas',
 '11.2 Es necesario que haya igual número de mujeres ganadoras del nobel de física como hombres',
 '11.3 Es normal que la mayoría de los ingenieros mecánicos sean varones porque los hombres son mejores para los números',
 '11.4 Las becas en áreas STEM que son sólo para mujeres discriminan a los hombres y generan desigualdad',
 '11.5 Que haya más físicos que físicas se explica por una historia de dominación masculina',
 '11.6 Muchas mujeres se caracterizan por una pureza que pocos hombres poseen',
 '11.7 Las mujeres deben ser queridas y protegidas por los hombres',
 '11.8 Todo hombre debe tener una mujer a quien amar',
 '11.9 El hombre está incompleto sin la mujer',
 '11.10 Las mujeres en comparación con los hombres tienden a tener un sentido más refinado de la cultura y el buen gusto',
 '11.11 Los hombres deberían estar dispuestos a sacrificar su propio bienestar con el fin de proveer seguridad económica a las mujeres']

de_acuerdo= {
    1: 'Totalmente en desacuerdo', 
    2: 'En desacuerdo',
    3: 'Neutro',
    4: 'De acuerdo',
    5: 'Totalmente de acuerdo'
}

df_mentores.loc[:, genero_acuerdo] = df_mentores.loc[:,genero_acuerdo].replace(de_acuerdo)
df_mentores.loc[:, genero_acuerdo]
# Out:
#     11.1 Es preferible que las mujeres enseñen ciencias sociales y los hombres ciencias exactas  \
# 0                             Totalmente en desacuerdo
# 1                             Totalmente en desacuerdo
# 2                             Totalmente en desacuerdo
# 3                             Totalmente en desacuerdo
# 4                             Totalmente en desacuerdo
# ..                                                 ...
# 113                              Totalmente de acuerdo
# 114                           Totalmente en desacuerdo
# 115                                             Neutro
# 116                                      En desacuerdo
# 117                           Totalmente en desacuerdo
#
#     11.2 Es necesario que haya igual número de mujeres ganadoras del nobel de física como hombres  \
# 0                                Totalmente de acuerdo
# 1                             Totalmente en desacuerdo
# ...

# %%
#
conocimiento = [
    '22. La contaminación en las principales ciudades del país es algo que preocupa a los gobernantes. Las concentraciones de contaminantes se miden con un valor llamado el Índice de Calidad del Aire (ICA).  La siguiente tabla muestra los valores para los cuales el ICA representa una calidad del aire Buena, Regular, Mala, y Muy Mala.Como el programa que creó Nicolás mostró que el aire en el centro de la ciudad estaba muy contaminado en ciertos momentos, el alcalde decidió tomar medidas extremas. Revisa el siguiente programa y elije la opción que describe la medida que tomó el alcalde.',
    '23.1 Si, María está usando un algoritmo para encontrar su almuerzo',
    '23.2 No, María solo está buscando su almuerzo',
    '23.3 Si, María está dividiendo el problema en problemas más sencillos',
    '23.4 No, en ningún momento de habla de computadores',
    '23.5 Otra', 
    '27. María vive cerca de una montaña donde hace mucho calor en el día, pero mucho frío en la noche. Ella tiene calefacción y aire acondicionado en su apartamento, pero deben prenderlo desde la portería que está en el primer piso del edificio. María decidió     programar la Micro:bit para que envíe un mensaje de encender la calefacción cuando esté frío (menos de 15 grados) y encender el aire acondicionado cuando esté caliente (más de 25 grados).  ¿Cuál de los siguientes programas le podríafuncionar a María?                Imagen 1                 Imagen 2                   Imagen 3                 Imagen 4',
    'Andrea hizo un diagrama de flujo para diseñar el algoritmo que le permitirá encender automáticamente el ventilador cuando esté muy caliente su habitación. Sin embargo, no está segura de que funcione. ¿Qué le podrías recomendar?',
    'Considera el siguiente segmento de código:¿En qué orden deberá realizar las siguientes operaciones de manera que el valor de la variable “a” sea 15 al finalizar?',
    'Considera el siguiente código:Después de que se ejecute el código anterior, ¿Cuáles de los siguientes enunciados sonverdaderos?',
    'Considera el siguiente código:Sia=3, b=8 y c=10, ¿Qué imprimirá el programa?',
    'Considera el siguiente segmento de código:Seleccione el fragmento de código más correcto que resultará en el cálculo del área de la superficie de un cilindro, dada la fórmula:',
    'Considera el siguiente segmento de código¿Después de que el anterior código se ejecuta, cual es el valor de la variable secuela?',
    'Dada la definición de la función:¿Cuál de las siguientes afirmaciones describe mejor el llamado a la función sumar (8, 5, 12)?',
    'Juan y Andrea crearon un juego en la Micro:bit y lo compartieron con sus compañeros. Sin embargo, nadie parece entender de qué se trata.',
    'La alcaldía acaba de contratar a Valeria para hacer un programa en la Micro:bit que controle el alumbrado público de su ciudad. Utilizando el sensor de luz de la tarjeta Micro:bit, ella se dio cuenta que cuando mide niveles de luz con un valor por debajo     de 100, ya está suficientemente oscuro como para prender el alumbrado público. El programa que hizo funciona bien para prender el alumbrado de la ciudad, pero luego cuando amanece, las luces siguen encendidas durante todo el día.   Valeria no está segura cómo solucionarlo, pero tiene algunas ideas que cree que podrían funcionar. ¿Cuál de las siguientes opciones crees que debería usar Valeria?                 Imagen 1                  Imagen 2                    Imagen 3                  Imagen 4',
    'Suponiendo que “a” y “b” son variables booleanas. Considera la siguiente expresión lógica:¿Cuál de las siguientes afirmaciones describe de manera más precisa la evaluación de las expresiones?',
    'Teniendo en cuenta el siguiente fragmento de código, Alejandra responde a la pregunta ¿Cuál será el valor final de “Y”? afirmando que el valor final será 44. El código retorna 120   ¿Qué opinas de la respuesta de Alejandra?',
    'Tim examina cada una de las siguientes piezas de código y responde que la primera termina con X siendo igual a 5, y la segunda con X siendo igual a 16.¿Cuál es el error conceptual de Tim?',
    'Un ratón robot ha sido programado para seguir las siguientes instrucciones:(1)Sigue hacia abajo hasta que haya un cruce a uno de los lados(2) Cuando encuentres un cruce, atraviésalo(3) Vuelve al paso (1).Considera el siguiente laberinto para nuestro ratón robot. ¿En cuál de los tubos debería comenzar el robot para llegar al queso?',
]

df_mentores[conocimiento]
# Out:
#  Imagen 3
# 1                                             Imagen 4
# 2                                             Imagen 3
# 3                                             Imagen 3
# 4                                             Imagen 3
# ..                                                 ...
# 113                                           Imagen 1
# 114                                           Imagen 3
# 115                                           Imagen 3
# 116                                           Imagen 3
# 117                                           Imagen 3
#
#     Suponiendo que “a” y “b” son variables booleanas. Considera la siguiente expresión lógica:¿Cuál de las siguientes afirmaciones describe de manera más precisa la evaluación de las expresiones?  \
# 0    La segunda expresión es verdadera si “(a O b)”...
# 1    La segunda expresión es verdadera si “(a O b)”...
# 2    La segunda expresión es verdadera solamente si...
# ...

# %%
# 
c_abiertas = [
    '29. ¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?',
    '33. ¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?',
]

df_mentores[c_abiertas]
# Out:
#     29. ¿Cómo le ayudarías a Juan y Andrea a explicarle a sus compañeros de clase el juego que han diseñado?  \
# 0                                    Diagrama de flujo
# 1                             Explicar condicicionales
# 2                                          condiciones
# 3                                      Valor Aleatorio
# 4                               Que hayan mas opciones
# ..                                                 ...
# 113                            Aleatorio y condicional
# 114                          Como cuando hay una rifa
# 115                          Deben explicar el valor a
# 116                                 pantalla/presionar
# 117                          juego aleatorio de 0 a 10
#
#     33. ¿Cómo le ayudarías a comprender la diferencia entre los dos códigos?
# 0                                                  NaN
# 1    Se deberia explicar a Juan que a pesar que la ...
# 2    ES MÁS EFICIENTE EL CODIGO 1 YA QUE LLAMA A LA...
# ...

# %%
autoeficacia_acuerdo = [
    '13.1 Sé cómo resolver los problemas técnicos cuando fallan las TIC',
    '13.2 Puedo aprender sobre nuevas tecnologías fácilmente',
    '13.3 Sé cómo usar las TIC con los estudiantes en clase',
    '13.4 Me apoyo en mis colegas para resolver problemas sobre cómo trabajar algún tema',
    '13.5 Puedo hablar con otros docentes sobre el diseño de cursos',
    '13.6 Siento que tengo apoyo de otros docentes para el diseño de mis cursos',
    '13.7 No tengo con quién conversar sobre el diseño de mis cursos',
    '15.1 Usar el correo electrónico',
    '15.2 Crear y usar de modelos y simulaciones',
    '15.3 Automatizar tareas',
    '15.4 Usar Word',
    '15.5 Procesar Datos',
    '15.6 Resolver problemas a través de herramientas computacionales (como simulaciones)',
    '15.7 Resolver problemas a través de herramientas computacionales (como lenguajes de programación)',
    '16.1 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi trabajo',
    '16.2 Puedo definir el pensamiento computacional',
    '16.3 Puedo describir las prácticas y habilidades que componen el pensamiento computacional a mis estudiantes',
    '16.4 Puedo aplicar las prácticas y habilidades del pensamiento computacional a mi vida diaria',
    '16.5 Creo que tengo las habilidades para desarrollar el pensamiento computacional en mis estudiantes',
    '16.6 Puedo enseñar fácilmente sobre nuevas prácticas computacionales',
    '16.7 Puedo diseñar una clase que desarrolle el pensamiento computacional en los estudiantes',
    '16.8 Puedo seleccionar tecnologías para usar en mi salón de clases, que me permitan mejorar qué enseño y cómo enseño pensamiento computacional',
    '16.9 Puedo aplicar mis habilidades en pensamiento computacional para ayudar a los estudiantes a perseguir sus intereses individuales',
    '16.10 Puedo implementar y evaluar la idoneidad de una estrategia pedagógica que le permita a los estudiantes desarrollar pensamiento computacional ',
]


df_mentores.loc[:, autoeficacia_acuerdo] = df_mentores.loc[:, autoeficacia_acuerdo].replace(de_acuerdo)
df_mentores.loc[:, autoeficacia_acuerdo]
# Out:
#       De acuerdo
# 117                              Totalmente de acuerdo
#
#     13.2 Puedo aprender sobre nuevas tecnologías fácilmente  \
# 0                                Totalmente de acuerdo
# 1                                           De acuerdo
# 2                                Totalmente de acuerdo
# 3                                Totalmente de acuerdo
# 4                                Totalmente de acuerdo
# ..                                                 ...
# 113                                         De acuerdo
# 114                              Totalmente de acuerdo
# 115                              Totalmente de acuerdo
# 116                                         De acuerdo
# 117                              Totalmente de acuerdo
#
#     13.3 Sé cómo usar las TIC con los estudiantes en clase  \
# 0                                Totalmente de acuerdo
# 1                                           De acuerdo
# ...

# %%
#
autoeficacia_10 = [
    '18.1 Actividades desconectadas',
    '18.2 Usa-Modifica-Crea',
    '18.3 Clase magistral',
    '18.4 Enseñanza explícita y sin ambigüedades',
    '18.5 Marcha Silenciosa',
    '18.6 Aprendizaje basado en proyectos',
    '20.1 Le explicaría la respuesta correcta',
    '20.2 Le sugeriría ir paso a paso por el programa simulando su ejecución',
    '20.3 Le diría que revise sus notas',
    '20.4 Le sugeriría que revise las memorias colectivas',
    '20.5 Le sugeriría volver a leer el problema',
    '20.6 Le sugeriría intentar con varios valores para evaluar el programa',
    '20.7 Le explicaría el problema nuevamente'
]

df_mentores[autoeficacia_10]
# Out:
#      18.1 Actividades desconectadas  18.2 Usa-Modifica-Crea  \
# 0                                10                      10
# 1                                10                      10
# 2                                10                      10
# 3                                10                       8
# 4                                10                      10
# ..                              ...                     ...
# 113                               6                       8
# 114                              10                      10
# 115                              10                      10
# 116                               9                       9
# 117                              10                      10
#
#      18.3 Clase magistral  18.4 Enseñanza explícita y sin ambigüedades  \
# 0                       5                                           10
# 1                       4                                            8
# ...

# %% [markdown]
# Ya está el dataframe limpio, ahora se generarán los diferentes archivos:

# %%
df_mentores_genero = df_mentores.loc[:, compartidas+genero_si+genero_acuerdo]
df_mentores_autoeficacia = df_mentores.loc[:, compartidas+autoeficacia_acuerdo+autoeficacia_10]
df_mentores_conocimientos = df_mentores.loc[:, compartidas+conocimiento+c_abiertas]
df_mentores_v2 = df_mentores.loc[:, compartidas+genero_si+genero_acuerdo+autoeficacia_acuerdo+autoeficacia_10+conocimiento+c_abiertas]

# %%
df_mentores_genero.to_excel('pre_mentores_genero.xlsx', index=False, encoding='utf-8-sig')
df_mentores_autoeficacia.to_excel('pre_mentores_autoeficacia.xlsx', index=False, encoding='utf-8-sig')
df_mentores_conocimientos.to_excel('pre_mentores_conocimientos.xlsx', index=False, encoding='utf-8-sig')
df_mentores_v2.to_excel('pre_mentores_v2.xlsx', index=False, encoding='utf-8-sig')
